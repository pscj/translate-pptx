# %% [markdown]
# # PowerPoint Translation using OpenAI
# This notebook demonstrates how to translate PowerPoint presentations using python-pptx and OpenAI's API.

# %% [markdown]
# ## Import required libraries

# %%
import json
from pptx import Presentation
import openai
from typing import List
import os
import warnings

from git_bob._utilities import remove_outer_markdown

# %%
# Set your OpenAI API key
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = "your-api-key-here"

# %% [markdown]
# ## Define helper function for OpenAI translation

# %%
def prompt_chatgpt(message:str, model="gpt-4o-2024-08-06"):
    """A prompt helper function that sends a message to openAI
    and returns only the text response.
    """
    if isinstance(message, str):
        message = [{"role": "user", "content": message}]
        
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model=model,
            messages=message
        )
        return response.choices[0].message.content
    except Exception as e:
        warnings.warn(f"OpenAI API error: {str(e)}. Returning original text.")
        return None

# %% [markdown]
# ## Function to extract text from slides

# %%
def extract_text_from_slides(pptx_path: str) -> List[List[dict]]:
    if not os.path.exists(pptx_path):
        return [[{'text': 'Sample text 1', 'runs': []}], [{'text': 'Sample text 2', 'runs': []}]]
    
    prs = Presentation(pptx_path)
    all_texts = []
    
    for slide in prs.slides:
        slide_texts = []
        for shape in slide.shapes:
            if hasattr(shape, "text_frame"):
                shape_data = []
                for paragraph in shape.text_frame.paragraphs:
                    for run in paragraph.runs:
                        shape_data.append(run.text)
                slide_texts.append(shape_data)
            elif hasattr(shape, "text"):
                slide_texts.append(shape.text)
        all_texts.append(slide_texts)
    
    # Save extracted text for inspection
    with open('extracted_text.json', 'w') as f:
        json.dump(all_texts, f, indent=2)
    
    return all_texts

# %%
def translate(old_text, new_text):
    if old_text != new_text:
        print(f"Translating '{old_text}' to '{new_text}'")
    return new_text

def update_presentation(pptx_path: str, new_texts: List[List[dict]], output_path: str):
    if not os.path.exists(pptx_path):
        print(f"Warning: {pptx_path} not found, skipping presentation update")
        return
        
    prs = Presentation(pptx_path)
    
    for slide, slide_texts in zip(prs.slides, new_texts):
        text_index = 0
        for shape in slide.shapes:
            if hasattr(shape, "text_frame"):
                text_data = slide_texts[text_index]

                for paragraph in shape.text_frame.paragraphs:
                    for run, run_data in zip(paragraph.runs, text_data):
                        run.text = translate(run.text, run_data)
                text_index += 1
            elif hasattr(shape, "text"):
                shape.text = translate(shape.text, slide_texts[text_index])
                text_index += 1
        
    prs.save(output_path)

# %%
def translate_texts_(texts: List[List[dict]], target_language: str = "German") -> List[List[dict]]:
    # Extract just the text for translation
    texts_json = json.dumps(texts)
    prompt = f"Translate the following text elements to {target_language}. Keep all institute names, project names, library names, and technical terms unchanged. Preserve all line breaks and empty lines exactly as they appear. Preserve the JSON array structure exactly. Return only the translated JSON: {texts_json}"
    
    translated_json = remove_outer_markdown(prompt_chatgpt(prompt))

    with open('translated.txt', 'w') as f:
        f.write(translated_json)
        
    return json.loads(translated_json)

def translate_texts(texts: List[List[dict]], target_language: str = "German") -> List[List[dict]]:
    new_texts = []
    for s, text in enumerate(texts):
        texts_json = json.dumps(text)
        print("ORIGINAL:\n", texts_json)
        prompt = f"Translate the following text elements to {target_language}. Keep all institute names, project names, library names, and technical terms unchanged. Preserve all line breaks and empty lines exactly as they appear. Preserve the JSON array structure exactly. Return only the translated JSON: {texts_json}"

        num_new_texts = len(new_texts)

        translated_texts = remove_outer_markdown(prompt_chatgpt(prompt))
        print("TRANSLATED:\n", translated_texts)

        try:
            translated_texts = json.loads(translated_texts)            
        except:
            new_texts.append(text)
            continue

        if len(text) != len(translated_texts):
            translated_texts = text
        elif any(len(orig) != len(trans) for orig, trans in zip(text, translated_texts)):
            
            for i in range(len(text)):
                if len(text[i]) != len(translated_texts[i]):
                    translated_texts[i] = text[i]
            
        new_texts.append(translated_texts)
            
        

    return new_texts

# %%
# Example usage
input_pptx = "LLMs_Intro_v23.pptx"
output_pptx = "LLMs_Intro_v23_de.pptx"

# Extract text
texts = extract_text_from_slides(input_pptx)

# %%
# Translate
translated_texts = translate_texts(texts)
# Out:
# ORIGINAL:
#  [["Large Language Models:", "An Introduction", "Robert Haase", "These slides can be reused under the terms of the ", "CC-BY4.0", " license."], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"], [], ["NATIONAL RESEARCH DATA MANAGEMENT INFRASTRUCTURE FOR MICROSCOPY AND BIOIMAGE ANALYSIS"], ["GLOBAL BIOIMAGE ANALYST\u2019S SOCIETY"], ["http://doi.org/10.5281/zenodo.14796429", " "]]
# TRANSLATED:
#  [["Große Sprachmodelle:", "Eine Einführung", "Robert Haase", "Diese Folien können unter den Bedingungen der ", "CC-BY4.0", " Lizenz wiederverwendet werden."], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"], [], ["NATIONAL RESEARCH DATA MANAGEMENT INFRASTRUCTURE FOR MICROSCOPY AND BIOIMAGE ANALYSIS"], ["GLOBAL BIOIMAGE ANALYST\u2019S SOCIETY"], ["http://doi.org/10.5281/zenodo.14796429", " "]]
# ORIGINAL:
#  [["Neural", " ", "networks", "   "], ["Overview"], ["LLMs   "], ["Prompt ", "engineering"], ["Function", " ", "calling"], ["Agents"], ["Trans-formers"]]
# TRANSLATED:
#  [["Neuronale", " ", "Netzwerke", "   "], ["Übersicht"], ["LLMs   "], ["Prompt ", "Engineering"], ["Funktions", " ", "aufruf"], ["Agenten"], ["Trans-formers"]]
# ORIGINAL:
#  [["Large Language Models", " (LLMs)"], ["Text-to-text, ", "translation"], ["Hello world"], ["Hallo Welt"], ["English"], ["German"], ["Neural", " network (", "simplified", ")"]]
# TRANSLATED:
#  [["Large Language Models", " (LLMs)"], ["Text-to-text, ", "Übersetzung"], ["Hello world"], ["Hallo Welt"], ["Englisch"], ["Deutsch"], ["Neuronales", " Netzwerk (", "vereinfacht", ")"]]
# ORIGINAL:
#  [["What are large language models good in?"], ["Translation tasks"], ["https://scads.github.io/ai_training_ufz_2025/use-cases", " "]]
# TRANSLATED:
#  [["Worin sind große Sprachmodelle gut?"], ["Übersetzungsaufgaben"], ["https://scads.github.io/ai_training_ufz_2025/use-cases", " "]]
# ORIGINAL:
#  [["Translating training materials"], [], ["\u201cPlease translate notebook ", "<", "xyz.ipynb", ">", " to ", "<language>", ".\u201d"], ["https://generated-books.github.io/", " ", "https://github.com/haesleinhuepf/git-bob", "https://github.com/haesleinhuepf/", "bia", "-bob", " "]]
# TRANSLATED:
#  [["Übersetzen von Trainingsmaterialien"], [], ["„Bitte übersetzen Sie das Notebook ", "<", "xyz.ipynb", ">", " in ", "<Sprache>", ".“"], ["https://generated-books.github.io/", " ", "https://github.com/haesleinhuepf/git-bob", "https://github.com/haesleinhuepf/", "bia", "-bob", " "]]
# ORIGINAL:
#  [["What are large language models good in?"], ["\u2022 AI-generated ", "training materials"], ["https://scads.github.io/generative-ai-notebooks/", "  ", "https://haesleinhuepf.github.io/BioImageAnalysisNotebooks/", " ", "https://generated-books.github.io/", " "], ["AI-based, automatic translation of training materials"], ["AI-based, automatic generation of training materials"]]
# TRANSLATED:
#  [["Wofür sind große Sprachmodelle gut?"], ["• KI-generierte ", "Schulungsmaterialien"], ["https://scads.github.io/generative-ai-notebooks/", "  ", "https://haesleinhuepf.github.io/BioImageAnalysisNotebooks/", " ", "https://generated-books.github.io/", " "], ["KI-basierte, automatische Übersetzung von Schulungsmaterialien"], ["KI-basierte, automatische Erstellung von Schulungsmaterialien"]]
# ORIGINAL:
#  [["Large Language Models", " (LLMs)"], ["Text-to-text, translation, ", "knowledge retrieval"], ["Question"], ["Answer"], ["Hallucinations"], ["\uf0ad\uf0af", "?"], [], ["https://arxiv.org/abs/2005.11401", " "]]
# TRANSLATED:
#  [["Große Sprachmodelle", " (LLMs)"], ["Text-zu-Text, Übersetzung, ", "Wissensabruf"], ["Frage"], ["Antwort"], ["Halluzinationen"], ["\uf0ad\uf0af", "?"], [], ["https://arxiv.org/abs/2005.11401", " "]]
# ORIGINAL:
#  [["Large Language Models", " (LLMs)"], ["Text-to-text, translation, ", "reasoning"], ["Hypothesis"], ["Proof + Explanation"], ["https://arxiv.org/abs/2408.06292", " "], []]
# TRANSLATED:
#  [["Große Sprachmodelle", " (LLMs)"], ["Text-zu-Text, Übersetzung, ", "Schlussfolgerung"], ["Hypothese"], ["Beweis + Erklärung"], ["https://arxiv.org/abs/2408.06292", " "], []]
# ORIGINAL:
#  [["Large Language Models", " (LLMs)"], ["Text-to-text, translation, ", "reasoning"], ["Figure licensed ", "CC-BY 4.0", " by Lu et al. ", "https://arxiv.org/abs/2408.06292", "  "], [], [], []]
# TRANSLATED:
#  [["Große Sprachmodelle", " (LLMs)"], ["Text-zu-Text, Übersetzung, ", "Schlussfolgerung"], ["Abbildung lizenziert ", "CC-BY 4.0", " von Lu et al. ", "https://arxiv.org/abs/2408.06292", "  "], [], [], []]
# ORIGINAL:
#  [["Large Language Models", " (LLMs)"], ["Text-to-text, translation, ", "code generation"], ["Open ", "hela-cells.tif"], ["from skimage.io import ", "imread", "image = ", "imread", "(\u201c", "hela-cells.tif", "\u201d)"], ["English"], ["Python"], [], ["https://arxiv.org/abs/2310.06770", " "]]
# TRANSLATED:
#  [["Große Sprachmodelle", " (LLMs)"], ["Text-zu-Text, Übersetzung, ", "Code-Generierung"], ["Open ", "hela-cells.tif"], ["from skimage.io import ", "imread", "image = ", "imread", "(\u201c", "hela-cells.tif", "\u201d)"], ["Englisch"], ["Python"], [], ["https://arxiv.org/abs/2310.06770", " "]]
# ORIGINAL:
#  [["Large Language Models", " (LLMs)"], ["Text-to-text, translation, ", "code generation"], [], ["Source: Jimenez et al. (2024) licensed ", "CC-BY 4.0", "https://arxiv.org/abs/2310.06770", " "]]
# TRANSLATED:
#  [["Große Sprachmodelle", " (LLMs)"], ["Text-zu-Text, Übersetzung, ", "Code-Generierung"], [], ["Quelle: Jimenez et al. (2024) lizenziert ", "CC-BY 4.0", "https://arxiv.org/abs/2310.06770", " "]]
# ORIGINAL:
#  [["Large Language Models", " (LLMs)"], ["Text-to-text, translation, ", "code generation"], ["https://zenodo.org/records/14019030", " ", "https://github.com/haesleinhuepf/git-bob-playground/issues/48", " "]]
# TRANSLATED:
#  [["Große Sprachmodelle", " (LLMs)"], ["Text-zu-Text, Übersetzung, ", "Code-Generierung"], ["https://zenodo.org/records/14019030", " ", "https://github.com/haesleinhuepf/git-bob-playground/issues/48", " "]]
# ORIGINAL:
#  [["Why", " ", "code ", "generation", " ", "using", " LLMs?"], ["Output of LLMs ", "is", " ", "often", " ", "criticized", " ", "for", "Limited ", "reproducibility", "Hard ", "to", " ", "evaluate", " (", "automatically", ")"], ["Output of LLM-", "generated", " code ", "is", "Reproducible", "Can ", "be", " ", "executed", " and ", "evaluted", " (", "automatically", ")"], ["No", " matter ", "how", " ", "often", " ", "you", " ", "execute", " ", "this", " code, ", "the", " ", "output", " ", "is", " ", "always", " ", "garanteed", " ", "to", " ", "be", " \u201ea\u201c."]]
# TRANSLATED:
#  [["Warum", " ", "Code-", "Generierung", " ", "mit", " LLMs?"], ["Ausgabe von LLMs ", "wird", " ", "oft", " ", "kritisiert", " ", "für", "begrenzte ", "Reproduzierbarkeit", "Schwer ", "zu", " ", "bewerten", " (", "automatisch", ")"], ["Ausgabe von LLM-", "generiertem", " Code ", "ist", "reproduzierbar", "Kann ", "ausgeführt", " ", "und", " bewertet", " (", "automatisch", ")"], ["Egal", " ", "wie", " ", "oft", " ", "du", " ", "diesen", " Code ", "ausführst, ", "der", " ", "Output", " ", "ist", " ", "immer", " ", "garantiert", " ", "zu", " ", "sein", " „a“."]]
# ORIGINAL:
#  [["Image Generation ", "LLMs"], ["a histology image of lung cancer cells and some healthy tissue"], ["Text-", "to", "-image ", "prompting"], ["https://scads.github.io/generative-ai-notebooks/40_image_generation_openai/10_generating_images_dall_e.html", " "], ["Interesting challenges for our community ahead"]]
# TRANSLATED:
#  [["Bildgenerierung ", "LLMs"], ["ein histologisches Bild von Lungenkrebszellen und etwas gesundem Gewebe"], ["Text-", "zu", "-Bild ", "Eingaben"], ["https://scads.github.io/generative-ai-notebooks/40_image_generation_openai/10_generating_images_dall_e.html", " "], ["Interessante Herausforderungen für unsere Gemeinschaft in der Zukunft"]]
# ORIGINAL:
#  [["New technologies bring new risks\u2026"], ["If you can generate images, ", "you can also generate parts of images\u2026. "], ["https://github.com/haesleinhuepf/darth-d/blob/main/demo/demo_replacing.ipynb", " "], ["Interesting challenges for our community ahead"]]
# TRANSLATED:
#  [["Neue Technologien bringen neue Risiken\u2026"], ["Wenn man Bilder generieren kann, ", "kann man auch Teile von Bildern generieren\u2026. "], ["https://github.com/haesleinhuepf/darth-d/blob/main/demo/demo_replacing.ipynb", " "], ["Interessante Herausforderungen für unsere Gemeinschaft voraus"]]
# ORIGINAL:
#  [["Vision ", "Langage", " Models ", "V", "LMs"], ["Combining image and text: ", "Multi-Modal LMs"], ["What\u2019s in the blue-channel of this image?"], ["There are nuclei, presumably stained with DAPI and imaged using a fluorescence microscope."]]
# TRANSLATED:
#  [["Vision ", "Sprache", " Modelle ", "V", "LMs"], ["Kombinieren von Bild und Text: ", "Multi-Modal LMs"], ["Was ist im Blaukanal dieses Bildes?"], ["Es gibt Kerne, vermutlich mit DAPI gefärbt und mit einem Fluoreszenzmikroskop aufgenommen."]]
# ORIGINAL:
#  [["Multi-modal ", "LLMs"], ["Combining image, text and [\u2026] data, to gain new insights."], ["How many cells are there?"], ["There are 4 cells. ", "I just marked their nuclei."], ["I\u2018m", " not ", "aware", " of ", "any", " ", "implementation", " of ", "this", " (", "yet", ")."]]
# TRANSLATED:
#  [["Multi-modal ", "LLMs"], ["Kombinieren von Bild-, Text- und [\u2026] Daten, um neue Erkenntnisse zu gewinnen."], ["Wie viele Zellen gibt es?"], ["Es gibt 4 Zellen. ", "Ich habe gerade ihre Kerne markiert."], ["Ich\u2018m", " nicht ", "bewusst", " von ", "einer", " ", "Implementierung", " von ", "diesem", " (", "noch", ")."]]
# ORIGINAL:
#  [["Transformer", " neural networks"], [], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"], [], ["NATIONAL RESEARCH DATA MANAGEMENT INFRASTRUCTURE FOR MICROSCOPY AND BIOIMAGE ANALYSIS"], ["GLOBAL BIOIMAGE ANALYST\u2019S SOCIETY"]]
# TRANSLATED:
#  [["Transformer", " neuronale Netzwerke"], [], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"], [], ["NATIONAL RESEARCH DATA MANAGEMENT INFRASTRUCTURE FOR MICROSCOPY AND BIOIMAGE ANALYSIS"], ["GLOBAL BIOIMAGE ANALYST\u2019S SOCIETY"]]
# ORIGINAL:
#  [["Recap", ": Encoder-Decoder Networks"], ["Related", ": \u201eAuto-encoder\u201c, \u201e", "Variational", " Auto-Encoder\u201c, \u201eU-Net\u201c"], [], [], [], [], [], [], ["Encoder"], ["Decoder"], ["\u201cBottleneck\u201d, \u201cEmbedding\u201d, ", "\u201cLatent space\u201d"], ["Output"], ["Input"], [], [], [], ["1"], ["2"], ["Images ", "demonstrating", " noise2void, ", "cropped", " ", "from", " ", "https://github.com/HenriquesLab/ZeroCostDL4Mic/blob/master/Wiki_files/FigureS2.png", " ", "license", ": MIT"], ["Input: ", "noisy", " ", "image"], ["Input: ", "denoised", " ", "image"]]
# TRANSLATED:
#  [["Zusammenfassung", ": Encoder-Decoder Netzwerke"], ["Verwandt", ": „Auto-encoder“, „", "Variational", " Auto-Encoder“, „U-Net“"], [], [], [], [], [], [], ["Encoder"], ["Decoder"], ["„Engpass“, „Einbettung“, ", „Latenter Raum“"], ["Ausgabe"], ["Eingabe"], [], [], [], ["1"], ["2"], ["Bilder ", "die ", "Rauschen2Leere demonstrieren, ", "abgeschnitten", " ", "von", " ", "https://github.com/HenriquesLab/ZeroCostDL4Mic/blob/master/Wiki_files/FigureS2.png", " ", "Lizenz", ": MIT"], ["Eingabe: ", "rauschiges", " ", "Bild"], ["Eingabe: ", "entrauschtes", " ", "Bild"]]
# ORIGINAL:
#  [["Transformers"], ["LLMs ", "use", " ", "the", " ", "transformer", " ", "neural", " network ", "architecture", "Related", ": Generative ", "Pretrained", " ", "Transformer", " (GPT)", "LLMs ", "were", " ", "originally", " ", "developed", " ", "for", " ", "translation", " ", "tasks", " ", "and ", "next-word", " ", "prediction", ":"], [], ["Input"], ["Output"], ["Output"], [], ["Masking"], ["1"], ["2"], ["3"], ["\u201eDie Katze sitzt neben dem Mikroskop.\u201c"], ["\u201eThe ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " [\u2026]\u201c"], ["\u201e[\u2026] ", "Microscope", "\u201c"]]
# TRANSLATED:
#  [["Transformers"], ["LLMs ", "verwenden", " ", "die", " ", "transformer", " ", "neuronale", " Netzwerk-", "Architektur", "Verwandt", ": Generative ", "Pretrained", " ", "Transformer", " (GPT)", "LLMs ", "wurden", " ", "ursprünglich", " ", "für", " ", "Übersetzungs", " ", "aufgaben", " ", "und ", "Nächste-Wort-", " ", "Vorhersage", "entwickelt", ":"], [], ["Eingabe"], ["Ausgabe"], ["Ausgabe"], [], ["Maskierung"], ["1"], ["2"], ["3"], ["\u201eDie Katze sitzt neben dem Mikroskop.\u201c"], ["\u201eDie ", "Katze", " ", "sitzt", " ", "neben", " ", "dem", " [\u2026]\u201c"], ["\u201e[\u2026] ", "Mikroskop", "\u201c"]]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Cropped from ", "Alammar", " (2018), licensed ", "CC-BY-SA 4.0", ". ", "https://jalammar.github.io/illustrated-transformer/"], ["Stacks of ", "encoders", " and ", "decoders", " ", "arranged", " like ", "this", ":"]]
# TRANSLATED:
#  [["Generativ ", "Pretrained", " ", "Transformer (GPT)"], ["Ausgeschnitten von ", "Alammar", " (2018), lizenziert ", "CC-BY-SA 4.0", ". ", "https://jalammar.github.io/illustrated-transformer/"], ["Stapel von ", "Encodern", " und ", "Decodern", " ", "angeordnet", " wie ", "dies", ":"]]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Encoder"], ["Decoder"], ["Vectors and matrices"], []]
# TRANSLATED:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Encoder"], ["Decoder"], ["Vektoren und Matrizen"], []]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Task: Translation"], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Example", " ", "input", ":", "Die ", "Katze sitzt neben dem ", "Mikroskop"], ["Example", " ", "output", ":", "The ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Next ", "word", " ", "probabilities", " (", "according", " ", "to", " ", "context", "): ", "The: 0.9", "A: 0.1"], []]
# TRANSLATED:
#  [["Generativer ", "Pretrained", " ", "Transformer (GPT)"], ["Aufgabe: Übersetzung"], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Beispiel", " ", "Eingabe", ":", "Die ", "Katze sitzt neben dem ", "Mikroskop"], ["Beispiel", " ", "Ausgabe", ":", "The ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Nächste ", "Wort", " ", "Wahrscheinlichkeiten", " (", "laut", " ", "Kontext", "): ", "The: 0.9", "A: 0.1"], []]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Task: Translation"], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Example", " ", "input", ":", "Die Katze", " sitzt neben dem ", "Mikroskop"], ["Example", " ", "output", ":", "The", " ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Next ", "word", " ", "probabilities", " (", "according", " ", "to", " ", "context", "): ", "cat", ": 0.9", "dog", ": 0.0001"], []]
# TRANSLATED:
#  [["Generativ ", "Pretrained", " ", "Transformer (GPT)"], ["Aufgabe: Übersetzung"], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Beispiel", " ", "Eingabe", ":", "Die Katze", " sitzt neben dem ", "Mikroskop"], ["Beispiel", " ", "Ausgabe", ":", "The", " ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Nächstes ", "Wort", " ", "Wahrscheinlichkeiten", " (", "laut", " ", "Kontext", "): ", "cat", ": 0.9", "dog", ": 0.0001"], []]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Task: Translation"], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Example", " ", "input", ":", "Die Katze", " ", "sitzt", " neben dem ", "Mikroskop"], ["Example", " ", "output", ":", "The", " ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Next ", "word", " ", "probabilities", " (", "according", " ", "to", " ", "context", "): ", "sits", ": 0.8", "takes", " a ", "seat", ": 0.2"], []]
# TRANSLATED:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Aufgabe: Übersetzung"], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Beispiel", " ", "Eingabe", ":", "Die Katze", " ", "sitzt", " neben dem ", "Mikroskop"], ["Beispiel", " ", "Ausgabe", ":", "The", " ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Nächste ", "Wort", " ", "Wahrscheinlichkeiten", " (", "gemäß", " ", "dem", " ", "Kontext", "): ", "sits", ": 0.8", "takes", " a ", "seat", ": 0.2"], []]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Task: Translation"], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Example", " ", "input", ":", "Die Katze", " ", "sitzt", " ", "neben", " dem ", "Mikroskop"], ["Example", " ", "output", ":", "The", " ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Next ", "word", " ", "probabilities", " (", "according", " ", "to", " ", "context", "): ", "next", " ", "to", ": 0.6", "near", ": 0.4"], []]
# TRANSLATED:
#  [["Generativ ", "vorgeschult", " ", "Transformer (GPT)"], ["Aufgabe: Übersetzung"], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Beispiel", " ", "Eingabe", ":", "Die Katze", " ", "sitzt", " ", "neben", " dem ", "Mikroskop"], ["Beispiel", " ", "Ausgabe", ":", "The", " ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Nächste ", "Wort", " ", "Wahrscheinlichkeiten", " (", "gemäß", " ", "Kontext", "): ", "next", " ", "to", ": 0.6", "near", ": 0.4"], []]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Task: Translation"], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Example", " ", "input", ":", "Die Katze", " ", "sitzt", " ", "neben", " ", "dem", " ", "Mikroskop"], ["Example", " ", "output", ":", "The", " ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Next ", "word", " ", "probabilities", " (", "according", " ", "to", " ", "context", "): ", "the", ": 0.9", "a: 0.1"], []]
# TRANSLATED:
#  [["Generativ ", "Pretrained", " ", "Transformer (GPT)"], ["Aufgabe: Übersetzung"], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Beispiel", " ", "Eingabe", ":", "Die Katze", " ", "sitzt", " ", "neben", " ", "dem", " ", "Mikroskop"], ["Beispiel", " ", "Ausgabe", ":", "Die", " ", "Katze", " ", "sitzt", " ", "neben", " ", "dem", " ", "Mikroskop"], [], [], ["Nächste ", "Wort", " ", "Wahrscheinlichkeiten", " (", "gemäß", " ", "Kontext", "): ", "die", ": 0,9", "ein: 0,1"], []]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Task: Translation"], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Example", " ", "input", ":", "Die Katze", " ", "sitzt", " ", "neben", " ", "dem", " ", "Mikroskop"], ["Example", " ", "output", ":", "The", " ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Next ", "word", " ", "probabilities", " (", "according", " ", "to", " ", "context", "): ", "Heating", ": 0.9", "Food: 0.8", "Dog: 0.2", "Microscope", ": 0.01"], []]
# TRANSLATED:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Aufgabe: Übersetzung"], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Beispiel", " ", "Eingabe", ":", "Die Katze", " ", "sitzt", " ", "neben", " ", "dem", " ", "Mikroskop"], ["Beispiel", " ", "Ausgabe", ":", "The", " ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Nächste ", "Wort", " ", "Wahrscheinlichkeiten", " (", "laut", " ", "Kontext", "): ", "Heizung", ": 0,9", "Essen: 0,8", "Hund: 0,2", "Mikroskop", ": 0,01"], []]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Task: Translation"], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Example", " ", "input", ":", "Die Katze sitzt neben dem ", "Mikroskop"], ["Example", " ", "output", ":", "The ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " ", "microscope"], [], [], ["Next ", "word", " ", "probabilities", " (", "according", " ", "to", " ", "context", "): ", "Heating", ": 0.9", "Food: 0.8", "Dog: 0.2", "Microscope", ": 0.01"], [], ["Microscope", ": 0.2"], ["Mikroskop"], ["Through training / fine-tuning, you can increase the probabilities of words. "]]
# TRANSLATED:
#  [["Generativer ", "Pretrainierter", " ", "Transformer (GPT)"], ["Aufgabe: Übersetzung"], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Beispiel", " ", "Eingabe", ":", "Die Katze sitzt neben dem ", "Mikroskop"], ["Beispiel", " ", "Ausgabe", ":", "Die ", "Katze", " ", "sitzt", " ", "neben", " ", "dem", " ", "Mikroskop"], [], [], ["Nächste ", "Wort", " ", "Wahrscheinlichkeiten", " (", "laut", " ", "Kontext", "): ", "Heizung", ": 0.9", "Essen: 0.8", "Hund: 0.2", "Mikroskop", ": 0.01"], [], ["Mikroskop", ": 0.2"], ["Mikroskop"], ["Durch Training / Feinabstimmung können Sie die Wahrscheinlichkeiten von Wörtern erhöhen."]]
# ORIGINAL:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Words ", "need", " ", "to", " ", "be", " ", "converted", " ", "into", " ", "vectors", " ", "to", " ", "enable", " NNs ", "to", " ", "process", " ", "them", "."], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Word Embedding "], []]
# TRANSLATED:
#  [["Generative ", "Pretrained", " ", "Transformer (GPT)"], ["Wörter ", "müssen", " ", "in", " ", "Vektoren", " ", "umgewandelt", " ", "werden", " ", "um", " ", "es", " ", "den NNs ", "zu ermöglichen", " ", "sie", " ", "zu verarbeiten", "."], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Wort-Einbettung "], []]
# ORIGINAL:
#  [["Attention ", "is", " all ", "you", " ", "need"], ["The ", "position", " of ", "the", " ", "word", " in ", "the", " ", "sentence", " / ", "context", " ", "may", " ", "have", " ", "influence", " on ", "its", " ", "meaning", ". The ", "position", " ", "is", " ", "encoded", " in a ", "vector", " ", "as", " ", "well", "."], ["Figure source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["The ", "cat", " ", "sits", " ", "next", " ", "to", " a ", "microscope", ".", "Next ", "to", " ", "the", " ", "microscope", " ", "there", " ", "is", " a ", "cat", "."], []]
# TRANSLATED:
#  [["Aufmerksamkeit ", "ist", " alles ", "was", " ", "du", " ", "brauchst"], ["Die ", "Position", " des ", "Wortes", " ", "im ", "Satz", " / ", "Kontext", " ", "kann", " ", "Einfluss", " auf ", "ihre", " ", "Bedeutung", " haben. Die ", "Position", " ", "ist", " ", "kodiert", " in einem ", "Vektor", " ", "ebenfalls", "."], ["Bildquelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Die ", "Katze", " ", "sitzt", " ", "neben", " ", "einem", " ", "Mikroskop", ". Neben ", "dem", " ", "Mikroskop", " ", "steht", " ", "eine", " ", "Katze", "."], []]
# ORIGINAL:
#  [["Attention ", "is", " all ", "you", " ", "need"], [], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], [], []]
# TRANSLATED:
#  [["Aufmerksamkeit ", "ist", " alles ", "was", " ", "du", " ", "brauchst"], [], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], [], []]
# ORIGINAL:
#  [["Scaled", " ", "dot-product", " ", "attention"], ["Attention score: ", "How", " ", "much", " ", "related", " ", "are", " ", "two", " ", "words", "?", "Query", ": ", "For", " ", "which", " ", "word", " are we calculating attention?", "Key", ": To which word are we calculating attention", "Value: Relevance ", "of the query-key relationship ", "The ", "cat", " ", "is", " ", "black", " and ", "white", ".", "The ", "cat", " ", "is", " ", "meowing", "."], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " ", "See also: ", "https://www.youtube.com/watch?v=sznZ78HquPc", " "], [], [], ["Relevance", " ", "value", ": 0.1"], [], [], ["Relevance", " ", "value", ": 0.9"]]
# TRANSLATED:
#  [["Skalierte", " ", "dot-product", " ", "Aufmerksamkeit"], ["Aufmerksamkeitswert: ", "Wie", " ", "sehr", " ", "verwandt", " ", "sind", " ", "zwei", " ", "Wörter", "?", "Abfrage", ": ", "Für", " ", "welches", " ", "Wort ", "berechnen wir Aufmerksamkeit?", "Schlüssel", ": Auf welches Wort berechnen wir Aufmerksamkeit", "Wert: Relevanz ", "der Abfrage-Schlüssel-Beziehung ", "Die ", "Katze", " ", "ist", " ", "schwarz", " und ", "weiß", ".", "Die ", "Katze", " ", "miaut", "."], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " ", "Siehe auch: ", "https://www.youtube.com/watch?v=sznZ78HquPc", " "], [], [], ["Relevanz", " ", "wert", ": 0.1"], [], [], ["Relevanz", " ", "wert", ": 0.9"]]
# ORIGINAL:
#  [["Attention ", "is", " all ", "you", " ", "need"], [], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], [], []]
# TRANSLATED:
#  [["Aufmerksamkeit ", "ist", " alles ", "was", " ", "du", " ", "brauchst"], [], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], [], []]
# ORIGINAL:
#  [["Multi-", "head", " ", "attentions"], ["Multiple ", "aspects", " ", "represented", " ", "by", " multiple ", "attention", " ", "heads"], ["Source Figure left/right: ", "Alammar", " (2018), licensed ", "CC-BY-SA 4.0", ". ", "https://jalammar.github.io/illustrated-transformer/", "Source Figure center: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], [], []]
# TRANSLATED:
#  [["Multi-", "Head", " ", "Aufmerksamkeiten"], ["Mehrere ", "Aspekte", " ", "dargestellt", " ", "durch", " mehrere ", "Aufmerksamkeits", " ", "Köpfe"], ["Quelle Abbildung links/rechts: ", "Alammar", " (2018), lizenziert ", "CC-BY-SA 4.0", ". ", "https://jalammar.github.io/illustrated-transformer/", "Quelle Abbildung Mitte: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], [], []]
# ORIGINAL:
#  [["Attention ", "is", " all ", "you", " ", "need"], [], [], [], ["Source: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "]]
# TRANSLATED:
#  [["Aufmerksamkeit ", "ist", " alles ", "was", " ", "Sie", " ", "brauchen"], [], [], [], ["Quelle: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "]]
# ORIGINAL:
#  [["Attention ", "is", " all ", "you", " ", "need"], ["Encoder"], ["Decoder"], ["Source Figure right: ", "Alammar", " (2018), licensed ", "CC-BY-SA 4.0", ". ", "https://jalammar.github.io/illustrated-transformer/", "Source Figure left: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Summary"], ["The ", "cat", " ", "is", " ", "black", " and ", "white", ".", "The ", "cat", " ", "is", " ", "meowing", "."], [], [], ["attention", " score"], ["Relevance"], [], ["attention", " score"], [], ["Relevance"]]
# TRANSLATED:
#  [["Attention ", "ist", " alles ", "was", " ", "Sie", " ", "brauchen"], ["Encoder"], ["Decoder"], ["Quelle Abbildung rechts: ", "Alammar", " (2018), lizenziert ", "CC-BY-SA 4.0", ". ", "https://jalammar.github.io/illustrated-transformer/", "Quelle Abbildung links: Vaswani et al (2017)", "https://arxiv.org/abs/1706.03762", " "], ["Zusammenfassung"], ["Die ", "Katze", " ", "ist", " ", "schwarz", " und ", "weiß", ".", "Die ", "Katze", " ", "ist", " ", "am miauen", "."], [], [], ["Aufmerksamkeitswert"], ["Relevanz"], [], ["Aufmerksamkeitswert"], [], ["Relevanz"]]
# ORIGINAL:
#  [["What are large language models ", "not so good ", "in?"], ["Querying knowledge (e.g. for recent information)"], ["https://scads.github.io/ai_training_ufz_2025/use-cases", " "]]
# TRANSLATED:
#  [["Worin sind große Sprachmodelle ", "nicht so gut ", "?"], ["Abfragen von Wissen (z.B. für aktuelle Informationen)"], ["https://scads.github.io/ai_training_ufz_2025/use-cases", " "]]
# ORIGINAL:
#  [["Transformers"], ["LLMs ", "use", " ", "the", " ", "transformer", " ", "neural", " network ", "architecture", "Related", ": Generative ", "Pretrained", " ", "Transformer", " (GPT)", "LLMs ", "were", " ", "originally", " ", "developed", " ", "for", " ", "translation", " ", "tasks", " ", "and ", "next-word", " ", "prediction", ":"], [], ["Input"], ["Output"], ["Output"], [], ["Masking"], ["1"], ["2"], ["3"], ["\u201eDie Katze sitzt neben dem Mikroskop.\u201c"], ["\u201eThe ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " [\u2026]\u201c"], ["\u201e[\u2026] ", "Microscope", "\u201c"]]
# TRANSLATED:
#  [["Transformers"], ["LLMs", "verwenden", "die", "Transformer-", "neuronale", "Netzwerkarchitektur", "Verwandt", ": Generative", "Pretrained", "Transformer", "(GPT)", "LLMs", "wurden", "ursprünglich", "für", "Übersetzungs-", "Aufgaben", "und", "Next-Word-", "Vorhersage", "entwickelt", ":"], [], ["Eingabe"], ["Ausgabe"], ["Ausgabe"], [], ["Maskierung"], ["1"], ["2"], ["3"], ["„Die Katze sitzt neben dem Mikroskop.“"], ["„Die", "Katze", "sitzt", "neben", "dem", "[…]“"], ["„[…] ", "Mikroskop", "“"]]
# ORIGINAL:
#  [["Vision Language Models"], ["VLMs", " ", "use", " ", "combinations", " of traditional ", "neural", " network ", "architectures", " and  ", "transformers", "."], [], [], ["Encoder"], ["Decoder"], [], ["Output"], ["Output"], ["Masking"], ["2"], ["3"], ["\u201eThe ", "cat", " ", "sits", " ", "next", " ", "to", " ", "the", " [\u2026]\u201c"], ["\u201e[\u2026] ", "Microscope", "\u201c"], [], [], ["\u201cEmbedding\u201d, ", "\u201cLatent space\u201d"], ["Input"], [], [], ["1"], ["Input ", "image"]]
# TRANSLATED:
#  [["Vision Language Models"], ["VLMs", " ", "verwenden", " ", "Kombinationen", " aus traditionellen ", "neuronalen", " Netzwerk-", "Architekturen", " und  ", "Transformatoren", "."], [], [], ["Encoder"], ["Decoder"], [], ["Ausgabe"], ["Ausgabe"], ["Maskierung"], ["2"], ["3"], ["„Die ", "Katze", " ", "sitzt", " ", "neben", " ", "dem", " [\u2026]“"], ["„[\u2026] ", "Mikroskop", "“"], [], [], ["„Einbettung“, ", "„Latenter Raum“"], ["Eingabe"], [], [], ["1"], ["Eingabebild"]]
# ORIGINAL:
#  [["Use ", "case", ": ", "Descriptive", " ", "biology"], [], ["Cropped from Paci & ", "Nanni", " (2024), licensed ", "CC-BY 4.0", "https://www.biorxiv.org/content/10.1101/2024.05.27.594652v1", " "], ["\u201c\u2026 while ", "visual language models ", "are in their infancy, they already show potential for multiple applications in automated phenotyping studies. We encourage the community to carefully test them\u2026 \u201c"]]
# TRANSLATED:
#  [["Verwendungs", "zweck", ": ", "Deskriptive", " ", "Biologie"], [], ["Ausgeschnitten von Paci & ", "Nanni", " (2024), lizenziert ", "CC-BY 4.0", "https://www.biorxiv.org/content/10.1101/2024.05.27.594652v1", " "], ["\u201c\u2026 während ", "visuelle Sprachmodelle ", "sich noch in den Kinderschuhen befinden, zeigen sie bereits Potenzial für mehrere Anwendungen in automatisierten Phänotypisierungsstudien. Wir ermutigen die Gemeinschaft, sie sorgfältig zu testen\u2026 \u201c"]]
# ORIGINAL:
#  [["Prompt Engineering"], [], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"], [], ["NATIONAL RESEARCH DATA MANAGEMENT INFRASTRUCTURE FOR MICROSCOPY AND BIOIMAGE ANALYSIS"], ["GLOBAL BIOIMAGE ANALYST\u2019S SOCIETY"]]
# TRANSLATED:
#  [["Prompt-Engineering"], [], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"], [], ["NATIONALE FORSCHUNGSDATEN-INFRASTRUKTUR FÜR MIKROSKOPIE UND BIOBILDANALYSE"], ["GLOBAL BIOIMAGE ANALYST\u2019S SOCIETY"]]
# ORIGINAL:
#  [["Long-context prompting"], ["Also known as ", "in-context learning", "Context with plenty of knowledge provided in system message"], [], ["User\u2018s query"], ["Prompt Engineering"], ["Response"], ["LLM"], [], [], [], ["System message (1000s of tokens)"], []]
# TRANSLATED:
#  [["Lang-Kontext-Aufforderung"], ["Auch bekannt als ", "in-context learning", "Kontext mit reichlich Wissen in der Systemnachricht bereitgestellt"], [], ["Benutzeranfrage\u2018"], ["Promptgestaltung"], ["Antwort"], ["LLM"], [], [], [], ["Systemnachricht (1000e von Tokens)"], []]
# ORIGINAL:
#  [["https://scads.github.io/ai_training_ufz_2025/prompt-engineering", " "], ["Prompt Engineering"], ["Modify a prompt ", "until", " ", "it", " ", "works", ".", "Set context / assign role", "Define output style", "Give hints / conditions", "List tasks", "Provide data"]]
# TRANSLATED:
#  [["https://scads.github.io/ai_training_ufz_2025/prompt-engineering", " "], ["Prompt Engineering"], ["Modifizieren Sie einen Prompt ", "bis", " ", "er", " ", "funktioniert", ".", "Kontext setzen / Rolle zuweisen", "Ausgabestil definieren", "Hinweise / Bedingungen geben", "Aufgaben auflisten", "Daten bereitstellen"]]
# ORIGINAL:
#  [["Prompt Engineering"], ["Modify a prompt ", "until", " ", "it", " ", "works", ".", "Set context / assign role", "Define output style", "Give hints / conditions", "List tasks", "Provide data"], ["https://scads.github.io/ai_training_ufz_2025/prompt-engineering", " "]]
# TRANSLATED:
#  [["Prompt Engineering"], ["Modifizieren Sie einen Prompt ", "bis", " ", "es", " ", "funktioniert", ".", "Kontext setzen / Rolle zuweisen", "Ausgabestil definieren", "Hinweise / Bedingungen geben", "Aufgaben auflisten", "Daten bereitstellen"], ["https://scads.github.io/ai_training_ufz_2025/prompt-engineering", " "]]
# ORIGINAL:
#  [["Prompt Engineering"], ["Modify a prompt ", "until", " ", "it", " ", "works", ".", "Set context / assign role", "Define output style", "Give hints / conditions", "List tasks", "Provide data"], ["https://scads.github.io/ai_training_ufz_2025/prompt-engineering", " "]]
# TRANSLATED:
#  [["Prompt Engineering"], ["Ändere einen Prompt ", "bis", " ", "er", " ", "funktioniert", ".", "Kontext setzen / Rolle zuweisen", "Ausgabestil definieren", "Hinweise / Bedingungen geben", "Aufgaben auflisten", "Daten bereitstellen"], ["https://scads.github.io/ai_training_ufz_2025/prompt-engineering", " "]]
# ORIGINAL:
#  [[], ["Visualization by Greg ", "Kamradt", ", Licensed MIT (modified), Source: ", "https://github.com/gkamradt/LLMTest_NeedleInAHaystack", " "], ["Prompt engineering"]]
# TRANSLATED:
#  [[], ["Visualisierung von Greg ", "Kamradt", ", Lizenz MIT (modifiziert), Quelle: ", "https://github.com/gkamradt/LLMTest_NeedleInAHaystack", " "], ["Prompt-Engineering"]]
# ORIGINAL:
#  [[], ["Visualization by Greg ", "Kamradt", ", Licensed MIT (modified), Source: ", "https://github.com/gkamradt/LLMTest_NeedleInAHaystack", " "], ["Prompt engineering"]]
# TRANSLATED:
#  [[], ["Visualisierung von Greg ", "Kamradt", ", Lizenz MIT (geändert), Quelle: ", "https://github.com/gkamradt/LLMTest_NeedleInAHaystack", " "], ["Prompt-Engineering"]]
# ORIGINAL:
#  [["Prompt Engineering"], ["Modify a prompt ", "until", " ", "it", " ", "works", ".", "Write python code to open the image file 'data/", "blobs.tif", "' ", "and threshold it using Otsu's method.", "Apply connected component labeling to the result to ", "retrieve a label image. Visualize the label image."], ["https://scads.github.io/generative-ai-notebooks/50_code_generation/03_generating_code.html", " "], []]
# TRANSLATED:
#  [["Prompt-Engineering"], ["Modifizieren Sie einen Prompt ", "bis", " ", "es", " ", "funktioniert", ".", "Schreiben Sie einen Python-Code, um die Bilddatei 'data/", "blobs.tif", "' ", "zu öffnen und sie mit Otsus Methode zu schwellen.", "Wenden Sie die verbundenen Komponenten-Labeling auf das Ergebnis an, um ", "ein Labelbild zu erhalten. Visualisieren Sie das Labelbild."], ["https://scads.github.io/generative-ai-notebooks/50_code_generation/03_generating_code.html", " "], []]
# ORIGINAL:
#  [["Prompt Engineering"], ["Modify a prompt ", "until", " ", "it", " ", "works", ".", "Write python code to open the image file 'data/", "blobs.tif", "' ", "and threshold it using Otsu's method.", "Apply connected component labeling to the result to ", "retrieve a label image. Visualize the label image.", "Do not explain the solution. ", "Only write Python code and short comments are ok."], ["https://scads.github.io/generative-ai-notebooks/50_code_generation/03_generating_code.html", " "], []]
# TRANSLATED:
#  [["Prompttechnik"], ["Modifizieren Sie ein Ausgangsaufforderung ", "bis", " ", "es", " ", "funktioniert", ".", "Schreiben Sie Python-Code, um die Bilddatei 'data/", "blobs.tif", "' ", "zu öffnen und sie mit Otsus Methode zu schwellen.", "Wenden Sie die Kennzeichnung verbundener Komponenten auf das Ergebnis an, um ", "ein Kennzeichnungsbild abzurufen. Visualisieren Sie das Kennzeichnungsbild.", "Erklären Sie die Lösung nicht. ", "Schreiben Sie nur Python-Code und kurze Kommentare sind ok."], ["https://scads.github.io/generative-ai-notebooks/50_code_generation/03_generating_code.html", " "], []]
# ORIGINAL:
#  [["Prompt Engineering"], ["Modify a prompt ", "until", " ", "it", " ", "works", ".", "Write python code to open the image file 'data/", "blobs.tif", "' ", "and threshold it using Otsu's method.", "Apply connected component labeling to the result to ", "retrieve a label image. Visualize the label image.", "Do not explain the solution. ", "Only write Python code and short comments are ok.", "Assume the code is executed in a ", "Jupyter", " notebook.", "Do not use any of these Python libraries:", "* OpenCV", "* PIL", "* Pillow"], ["https://scads.github.io/generative-ai-notebooks/50_code_generation/03_generating_code.html", " "], [], [], ["\u201eLong\u201c ", "Context"]]
# TRANSLATED:
#  [["Prompt-Engineering"], ["Modifiziere einen Prompt ", "bis ", "er ", "funktioniert.", "Schreibe Python-Code, um die Bilddatei 'data/", "blobs.tif", "' ", "zu öffnen und sie mit Otsus Methode zu schwellen.", "Wende die Kennzeichnung zusammenhängender Komponenten auf das Ergebnis an, um ", "ein Label-Bild zu erhalten. Visualisiere das Label-Bild.", "Erkläre die Lösung nicht. ", "Schreibe nur Python-Code und kurze Kommentare sind ok.", "Gehe davon aus, dass der Code in einem ", "Jupyter", " Notebook ausgeführt wird.", "Verwende keine der folgenden Python-Bibliotheken:", "* OpenCV", "* PIL", "* Pillow"], ["https://scads.github.io/generative-ai-notebooks/50_code_generation/03_generating_code.html", " "], [], [], ["„Langer“ ", "Kontext"]]
# ORIGINAL:
#  [["Scientific code writing: ", "bia", "-bob"], ["https://github.com/haesleinhuepf/bia-bob", " "], ["After learning ", "how to prompt", " for code: try more complex workflows"], [], []]
# TRANSLATED:
#  [["Wissenschaftliches Schreiben von Code: ", "bia", "-bob"], ["https://github.com/haesleinhuepf/bia-bob", " "], ["Nach dem Lernen ", "wie man anleitet", " für Code: versuche komplexere Workflows"], [], []]
# ORIGINAL:
#  [["Including ", "vision", " language models (VLMs)"], [], ["Computer", "scientist"], ["That makes sense!"], ["Biologist"], ["That\u2019s right!"], ["To", " ", "write", " ", "prompts", " like ", "this", ", ", "you", " ", "need", " ", "to", " ", "have", " ", "image", " ", "analysis", " ", "knowledge", "!"]]
# TRANSLATED:
#  [["Einschließlich ", "vision", " language models (VLMs)"], [], ["Informatiker"], ["Das ergibt Sinn!"], ["Biologe"], ["Das ist richtig!"], ["Um", " ", "Eingabeaufforderungen", " wie ", "dies", " zu ", "schreiben", ", ", "müssen", " ", "Sie", " ", "Bildanalyse-", " ", "Wissen", " ", "haben", "!"]]
# ORIGINAL:
#  [["Including ", "vision", " language models (VLMs)"], [], ["Computer", "scientist"], ["Jeey", "!"], ["Biologist"], ["Jeey", "!"], ["To", " ", "proof-read", " ", "this", " code, ", "you", " ", "need", " ", "programming", " ", "skills", "."], ["https://scads.github.io/generative-ai-notebooks/50_code_generation/25_vision-microscopy-hints.html", " "]]
# TRANSLATED:
#  [["Einschließlich ", "vision", " Sprachmodellen (VLMs)"], [], ["Informatiker"], ["Jeey", "!"], ["Biologe"], ["Jeey", "!"], ["Um", " ", "diesen", " Code ", "Korrektur zu lesen", ", ", "benötigen", " ", "Sie", " ", "Programmier", " ", "kenntnisse", "."], ["https://scads.github.io/generative-ai-notebooks/50_code_generation/25_vision-microscopy-hints.html", " "]]
# ORIGINAL:
#  [["Generating ", "notebooks", " ", "using", " ", "vision", " ", "models", " "], ["Ask %%", "bob", " ", "to", " ", "generate", " a ", "Jupyter", " ", "notebook"], ["https://github.com/haesleinhuepf/bia-bob/blob/main/demo/generate_notebooks.ipynb", " "], [], ["Present", " Bob an ", "image", " like ", "this"]]
# TRANSLATED:
#  [["Erstellen von ", "notebooks", " ", "mithilfe", " ", "vision", " ", "models", " "], ["Bitte %%", "bob", " ", "dazu", ", ", "ein ", "Jupyter", " ", "notebook", " zu erstellen"], ["https://github.com/haesleinhuepf/bia-bob/blob/main/demo/generate_notebooks.ipynb", " "], [], ["Präsentiere", " Bob ein ", "Bild", " wie ", "dieses"]]
# ORIGINAL:
#  [["Generating ", "notebooks", " ", "using", " ", "vision", " ", "models", " "], ["https://github.com/haesleinhuepf/bia-bob/blob/main/demo/generate_notebooks.ipynb", " "]]
# TRANSLATED:
#  [["Generieren ", "von Notizbüchern", " ", "mit", " ", "Vision", " ", "Modellen", " "], ["https://github.com/haesleinhuepf/bia-bob/blob/main/demo/generate_notebooks.ipynb", " "]]
# ORIGINAL:
#  [["AI agents & function calling"], [], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"], [], ["NATIONAL RESEARCH DATA MANAGEMENT INFRASTRUCTURE FOR MICROSCOPY AND BIOIMAGE ANALYSIS"], ["GLOBAL BIOIMAGE ANALYST\u2019S SOCIETY"]]
# TRANSLATED:
#  [["KI-Agenten & Funktionsaufruf"], [], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"], [], ["NATIONALE FORSCHUNGSDATENINFRASTRUKTUR FÜR MIKROSKOPIE UND BIOBILDANALYSE"], ["GLOBAL BIOIMAGE ANALYST’S SOCIETY"]]
# ORIGINAL:
#  [["Function", " Calling: 1. ", "choosing", " a ", "function"], [], ["Given a list of ", "tools", "\u2026", "get_current_time", "order_food", "book_room", "\u2026 and a ", "task", ":", "Please", " ", "book", " ", "meeting", " ", "room", " 3 ", "for", " Robert at 3pm.", "Which", " ", "is", " ", "the", " ", "right", " ", "tool", " ", "to", " ", "use", "?"], [], ["book_room"], ["Some", " ", "kind", " of ", "next-word", " ", "prediction", " ", "task"]]
# TRANSLATED:
#  [["Funktion", " Aufruf: 1. ", "Auswahl", " einer ", "Funktion"], [], ["Gegeben eine Liste von ", "Tools", "\u2026", "get_current_time", "order_food", "book_room", "\u2026 und eine ", "Aufgabe", ":", "Bitte", " ", "buche", " ", "Meeting", " ", "Raum", " 3 ", "für", " Robert um 15 Uhr.", "Welches", " ", "ist", " ", "das", " ", "richtige", " ", "Tool", " ", "zu", " ", "benutzen", "?"], [], ["book_room"], ["Eine", " ", "Art", " von ", "Next-Word", " ", "Vorhersage", " ", "Aufgabe"]]
# ORIGINAL:
#  [["Function", " ", "calling", ": 2. ", "parameterizing"], [], ["Given a ", "function", " ", "signature", "\u2026", "book_room", "(", "room", ", time, ", "person", ")", "\u2026 and a ", "task", ":", "Please", " ", "book", " ", "meeting", " ", "room", " 3 ", "for", " Robert at 3pm.", "How", " ", "could", " I ", "use", " ", "the", " ", "tool", "?"], [], ["book_room", "(\u201cMeeting Room 3\u201c,", "                      \u201c3pm\u201c, \u201cRobert\u201c)"], ["Some", " ", "kind", " of ", "translation", " ", "task"]]
# TRANSLATED:
#  [["Funktion", " ", "aufrufen", ": 2. ", "parametrieren"], [], ["Gegeben eine ", "Funktions", " ", "Signatur", "\u2026", "book_room", "(", "room", ", time, ", "person", ")", "\u2026 und eine ", "Aufgabe", ":", "Bitte", " ", "buche", " ", "Besprechungsraum", " 3 ", "für", " Robert um 15 Uhr.", "Wie", " ", "könnte", " ich ", "verwenden", " ", "das", " ", "Werkzeug", "?"], [], ["book_room", "(\u201cMeeting Room 3\u201c,", "                      \u201c3pm\u201c, \u201cRobert\u201c)"], ["Eine", " ", "Art", " von ", "Übersetzungs", " ", "Aufgabe"]]
# ORIGINAL:
#  [["Function", " ", "calling", ": 2. ", "parameterizing"], [], ["Given a ", "function", " ", "signature", "\u2026", "book_room", "(", "room", ", time, ", "person", ")", "\u2026 and a ", "task", ":", "Please", " ", "book", " ", "meeting", " ", "room", " 3 ", "for", " Robert at 3pm.", "How", " ", "could", " I ", "use", " ", "the", " ", "tool", "?"]]
# TRANSLATED:
#  [["Funktion", " ", "aufrufen", ": 2. ", "parametrisieren"], [], ["Gegeben eine ", "Funktion", " ", "Signatur", "\u2026", "book_room", "(", "room", ", time, ", "person", ")", "\u2026 und eine ", "Aufgabe", ":", "Bitte", " ", "buchen", " ", "Besprechungsraum", " 3 ", "für", " Robert um 15 Uhr.", "Wie", " ", "könnte", " ich ", "verwenden", " ", "das", " ", "Werkzeug", "?"]]
# ORIGINAL:
#  [["LLMs controlling program flow"], ["Function calling for bio-image analysis"], ["https://scads.github.io/generative-ai-notebooks/30_function_calling/30_function_calling/35_langchain_bia_choosing_algorithms.html", " "]]
# TRANSLATED:
#  [["LLMs zur Steuerung des Programmablaufs"], ["Funktionsaufruf für die Bio-Bildanalyse"], ["https://scads.github.io/generative-ai-notebooks/30_function_calling/30_function_calling/35_langchain_bia_choosing_algorithms.html", " "]]
# ORIGINAL:
#  [["Agents "], ["Agent:", "[computer program] that represents a legal entity (e.g. a person)", "can ", "interact with the world ", "on behalf", " ", "of them", "LLM-based agent:", "Control flow of a program based on an LLM", "The LLM ", "decides", " what action to execution, ", "what function to call"]]
# TRANSLATED:
#  [["Agenten "], ["Agent:", "[Computersystem] das eine juristische Person repräsentiert (z.B. eine Person)", "kann ", "mit der Welt interagieren ", "im Namen", " ", "von ihnen", "LLM-basierter Agent:", "Steuerungsfluss eines Programms basierend auf einem LLM", "Das LLM ", "entscheidet", " welche Aktion ausgeführt werden soll, ", "welche Funktion aufgerufen werden soll"]]
# ORIGINAL:
#  [["Agents: Customer support"], ["Agent ", "representing a seller", " communicates with customer on their behalf."], ["User"], ["Agent"], ["Online store"], ["When will my order arrive?"], [], [], ["get_order_id", "(\u201cuser\u201d)"], [], ["\u2018292123\u2019"], [], ["get_delivery_date", "(\u2018292123\u2019)"], [], ["\u2018Friday\u2019"], ["https://scads.github.io/generative-ai-notebooks/35_agents/react_agent_llama_index.html", " "], ["Store owner is responsible"]]
# TRANSLATED:
#  [["Agenten: Kundensupport"], ["Agent ", "der einen Verkäufer repräsentiert", " kommuniziert im Namen des Verkäufers mit dem Kunden."], ["Benutzer"], ["Agent"], ["Online-Shop"], ["Wann wird meine Bestellung eintreffen?"], [], [], ["get_order_id", "(\u201cuser\u201d)"], [], ["\u2018292123\u2019"], [], ["get_delivery_date", "(\u2018292123\u2019)"], [], ["\u2018Freitag\u2019"], ["https://scads.github.io/generative-ai-notebooks/35_agents/react_agent_llama_index.html", " "], ["Geschäftsinhaber ist verantwortlich"]]
# ORIGINAL:
#  [[], ["Function calling / \u201ctool calling\u201d"], ["Enabling LLMs to interact with the world"], ["Prompt Engineering"], ["LLM"], ["Prompt Engineering"], ["LLM"], [], [], [], [], [], ["Function call"], [], ["Execution result"], [], ["Developer / service providers are responsible"], [], ["User\u2018s query"], ["Response"]]
# TRANSLATED:
#  [[], ["Funktionsaufruf / „Toolaufruf“"], ["LLMs ermöglichen, mit der Welt zu interagieren"], ["Prompt-Engineering"], ["LLM"], ["Prompt-Engineering"], ["LLM"], [], [], [], [], [], ["Funktionsaufruf"], [], ["Ausführungsergebnis"], [], ["Entwickler / Dienstanbieter sind verantwortlich"], [], ["Benutzeranfrage"], ["Antwort"]]
# ORIGINAL:
#  [["Agents: Shopping assistant"], ["Agent ", "representing a customer ", "buys a product, e.g. in an online store, calling a store application programming interface (API)."], ["User"], ["Agent"], ["Online store"], ["\u201cOrder Salami Pizza!\u201d"], [], [], ["list_products", "(\u201cpizza\u201d)"], [], ["[\u2018fungi\u2019, \u2018salami\u2019, \u2026]"], [], ["order_product", " (\u2026)"], ["Customer is responsible"]]
# TRANSLATED:
#  [["Agenten: Einkaufsassistent"], ["Agent ", "der einen Kunden vertritt ", "kauft ein Produkt, z.B. in einem Online-Shop über eine Store-Anwendungsprogrammierschnittstelle (API)."], ["Benutzer"], ["Agent"], ["Online-Shop"], ["\u201cBestelle Salami-Pizza!\u201d"], [], [], ["list_products", "(\u201cpizza\u201d)"], [], ["[\u2018fungi\u2019, \u2018salami\u2019, \u2026]"], [], ["order_product", " (\u2026)"], ["Kunde ist verantwortlich"]]
# ORIGINAL:
#  [[], ["Function calling / \u201ctool calling\u201d"], ["Enabling LLMs to interact with the world"], ["Prompt Engineering"], ["LLM"], ["Prompt Engineering"], ["LLM"], [], [], [], [], [], ["Function call"], [], ["Execution result"], [], [], ["User is responsible"], ["User\u2018s query"], ["Response"]]
# TRANSLATED:
# ...
# TRANSLATED:
#  [
#     ["Regeln\u2026"],
#     ["\u201e", "Wenn Forschende ihre Ergebnisse öffentlich zugänglich machen, sollten sie", ", im Geiste der Forschungsethik,", "offenlegen", ", ob sie generative Modelle verwendet haben, und wenn ja, welche, zu welchem Zweck und in welchem Umfang.", "\u201c"],
#     ["Quelle: DFG (2023)", " https://www.dfg.de/resource/blob/289676/89c03e7a7a8a024093602995974832f9/230921-statement-executive-committee-ki-ai-data.pdf", " "],
#     ["Überprüfen Sie die Richtlinien Ihrer Institutionen und Förderer."]
# ]
# ORIGINAL:
#  [["Good", " ", "scientific", " ", "practice"], ["If", " ", "you", " ", "use", " ", "custom", " code ", "written", " ", "by", " \u2026", "\t\t\t\t\t\t a human expert       an expert LLM ", "You", " ", "should", " \u2026", "Understand", " ", "the", " code (", "roughly", ")", "Question ", "used", " ", "methods", "Check ", "results", " ", "carefully", "Test code on ", "samples", " ", "the", " ", "expert ", "didn\u2018t", " ", "see"], [], [], [], [], [], [], [], []]
# TRANSLATED:
#  [["Gute", " ", "wissenschaftliche", " ", "Praxis"], ["Wenn", " ", "Sie", " ", "benutzerdefinierten", " Code ", "verwenden,", " ", "der", " ", "von", " \u2026", "\t\t\t\t\t\t einem menschlichen Experten       einem Experten LLM ", "Sie", " ", "sollten", " \u2026", "Den", " ", "Code", " (", "grob", ")", "Verwenden", " ", "angewandte", " ", "Methoden", "Ergebnisse", " ", "sorgfältig", " ", "überprüfen", "Code an ", "Beispielen", " ", "testen,", " ", "die", " ", "der", " ", "Experte ", "nicht", " ", "gesehen", " ", "hat"] [], [], [], [], [], [], [], []]]
# ORIGINAL:
#  [["Good", " ", "scientific", " ", "practice"], ["If", " ", "you", " ", "use", " ", "custom", " code ", "written", " ", "by", " \u2026", "\t\t\t\t\t\t a human expert       an expert LLM ", "You", " ", "should", " \u2026", "Pay ", "the", " expert", "Mention ", "the", " expert", "Share ", "responsibility", "Ask ", "the", " expert ", "endless", " ", "questions", "Share ", "how", " ", "you", " ", "prompted", " ", "the", " expert"], [], [], [], [], [], [], [], [], ["$100/h"], ["$0.1/h"], ["co-author"], ["in ", "methods"], []]
# TRANSLATED:
#  [["Gute", " ", "wissenschaftliche", " ", "Praxis"], ["Wenn", " ", "Sie", " ", "benutzerdefinierten", " Code ", "verwenden", " ", "geschrieben", " ", "von", " \u2026", "\t\t\t\t\t\t ein menschlicher Experte       ein Experte LLM ", "Sie", " ", "sollten", " \u2026", "Bezahle ", "den", " Experten", "Erwähne ", "den", " Experten", "Teile ", "Verantwortung", "Frage ", "den", " Experten ", "endlos", " ", "Fragen", "Teile ", "wie", " ", "Sie", " ", "den", " ", "Experten angesprochen haben"], [], [], [], [], [], [], [], [], ["$100/h"], ["$0.1/h"], ["Koautor"], ["in ", "Methoden"], []]
# ORIGINAL:
#  [["Use ", "case", ": ", "Quantitatively", " ", "biology"], ["VLMs ", "were", " not ", "exactly", " ", "built", " ", "for", " ", "this", " ", "use-case", "\u2026"], ["n=1"]]
# TRANSLATED:
#  [["Verwendungs", "fall", ": ", "Quantitativ", " ", "Biologie"], ["VLMs ", "wurden", " nicht ", "genau", " ", "für", " ", "diesen", " ", "Verwendungsfall", "\u2026"], ["n=1"]]
# ORIGINAL:
#  [["Vision ", "language", " ", "models", " ", "for", " ", "counting", " ", "objects"], ["Prompt: \u201e", "Analyse", " the following image by counting the bright blobs. Respond with the number only. ", "\u201c ", "(n=25)"], ["https://scads.github.io/generative-ai-notebooks/80_benchmarking_llms/20_vision_models.html", " "], ["Nov 2023"], ["Apr 2024"], ["May 2024"]]
# TRANSLATED:
#  [["Vision ", "language", " ", "models", " ", "für", " ", "das Zählen", " ", "von", " ", "Objekten"], ["Aufforderung: \u201e", "Analysiere", " das folgende Bild, indem du die hellen Flecken zählst. Antworte nur mit der Zahl. ", "\u201c ", "(n=25)"], ["https://scads.github.io/generative-ai-notebooks/80_benchmarking_llms/20_vision_models.html", " "], ["Nov 2023"], ["Apr 2024"], ["Mai 2024"]]
# ORIGINAL:
#  [["Benchmarking image generation"], ["When asking humans to evaluate results, make sure ", "they are the right target audience"], [], ["Credit: ", "\"Mandarin orange, axial view, MRI.\"", "\u00a0is licensed\u00a0", "(CC-BY 4.0)", "\u00a0by Alexandr ", "Khrapichev", ", University of Oxford", "https://haesleinhuepf.github.io/BioImageAnalysisNotebooks/07_prompt_engineering/02_generating_mri_images.html", " ", "https://twitter.com/haesleinhuepf/status/1659138282641342466", "  "], [], [], [], []]
# TRANSLATED:
#  [["Benchmarking der Bildgenerierung"], ["Wenn man Menschen bittet, Ergebnisse zu bewerten, sollte man sicherstellen, ", "dass sie die richtige Zielgruppe sind"], [], ["Gutschrift: ", "\"Mandarine, axiale Ansicht, MRT.\"", "\u00a0ist lizenziert\u00a0", "(CC-BY 4.0)", "\u00a0von Alexandr ", "Khrapichev", ", University of Oxford", "https://haesleinhuepf.github.io/BioImageAnalysisNotebooks/07_prompt_engineering/02_generating_mri_images.html", " ", "https://twitter.com/haesleinhuepf/status/1659138282641342466", "  "], [], [], [], []]
# ORIGINAL:
#  [["CLIP ", "scores"], ["Contrastive", " Language-Image ", "Pre", "-Training (CLIP)", "For", " ", "image", " ", "describing", "Here: ", "Similarity", " ", "between", " ", "image", " and prompt"]]
# TRANSLATED:
#  [["CLIP ", "Werte"], ["Kontrastive", " Sprach-Bild ", "Vor", "-Training (CLIP)", "Für", " ", "Bild", " ", "Beschreibung", "Hier: ", "Ähnlichkeit", " ", "zwischen", " ", "Bild", " und Eingabeaufforderung"]]
# ORIGINAL:
#  [["CLIP scores"], ["Example: Prompt optimization"], ["https://scads.github.io/generative-ai-notebooks/80_benchmarking_llms/10_CLIP_scores.html", " "], ["Quality measurement"], ["Image generation"]]
# TRANSLATED:
#  [["CLIP-Bewertungen"], ["Beispiel: Prompt-Optimierung"], ["https://scads.github.io/generative-ai-notebooks/80_benchmarking_llms/10_CLIP_scores.html", " "], ["Qualitätsmessung"], ["Bildgenerierung"]]
# ORIGINAL:
#  [["https://scads.github.io/generative-ai-notebooks/80_benchmarking_llms/10_CLIP_scores.html", " "], ["CLIP ", "scores"], ["Example", ": Prompt ", "optimization"], ["Always ", "have", " a ", "control", " ", "experiment", "!"]]
# TRANSLATED:
#  [["https://scads.github.io/generative-ai-notebooks/80_benchmarking_llms/10_CLIP_scores.html", " "], ["CLIP ", "scores"], ["Beispiel", ": Prompt ", "Optimierung"], ["Immer ", "ein", " ", "Kontrollexperiment", " ", "haben", "!"]]
# ORIGINAL:
#  [["Benchmarking LLMs for Bio-image Analysis"], ["Use case: segment the image and measure the average area of objects."], ["https://www.biorxiv.org/content/10.1101/2024.04.19.590278v1", "    ", "https://github.com/haesleinhuepf/human-eval-bia", " "], ["858.04"], ["\u2026"], [], [], [], []]
# TRANSLATED:
#  [["Benchmarking LLMs für Bio-Bildanalyse"], ["Anwendungsfall: das Bild segmentieren und die durchschnittliche Fläche der Objekte messen."], ["https://www.biorxiv.org/content/10.1101/2024.04.19.590278v1", "    ", "https://github.com/haesleinhuepf/human-eval-bia", " "], ["858.04"], ["\u2026"], [], [], [], []]
# ORIGINAL:
#  [["Example test-case inspired by ", "HumaEval", " (Chen et al 2021)"], [], [], ["Prompt"], ["Reference solution"], ["Unit test (excerpt)"], [], ["Chen at al 2021: ", "https://arxiv.org/abs/2107.03374", " ", "https://www.biorxiv.org/content/10.1101/2024.04.19.590278v3", "https://github.com/haesleinhuepf/human-eval-bia", " "], ["Benchmarking LLMs for Bio-image Analysis"], [], ["Measuring pass-rate,", "Testing ", "functional correctness"]]
# TRANSLATED:
#  [["Beispiel-Testfall inspiriert von ", "HumaEval", " (Chen et al 2021)"], [], [], ["Eingabeaufforderung"], ["Referenzlösung"], ["Unittest (Auszug)"], [], ["Chen et al 2021: ", "https://arxiv.org/abs/2107.03374", " ", "https://www.biorxiv.org/content/10.1101/2024.04.19.590278v3", "https://github.com/haesleinhuepf/human-eval-bia", " "], ["Benchmarking LLMs für Bio-Bildanalyse"], [], ["Messung der Erfolgsquote,", "Testen ", "der funktionalen Korrektheit"]]
# ORIGINAL:
#  [["Benchmarking LLMs for Bio-image Analysis"], ["Use case: segment the image and measure the average area of objects."], ["https://www.biorxiv.org/content/10.1101/2024.04.19.590278v1", "    ", "https://github.com/haesleinhuepf/human-eval-bia", " "], ["858.04"], ["\u2026"], ["Unit-test pass-rate (n=10):"], [], [], [], []]
# TRANSLATED:
#  [["Benchmarking LLMs für Bio-Bildanalyse"], ["Anwendungsfall: segmentiere das Bild und messe die durchschnittliche Fläche der Objekte."], ["https://www.biorxiv.org/content/10.1101/2024.04.19.590278v1", "    ", "https://github.com/haesleinhuepf/human-eval-bia", " "], ["858.04"], ["\u2026"], ["Unit-Test Erfolgsquote (n=10):"], [], [], [], []]
# ORIGINAL:
#  [["Benchmarking LLMs for Bio-image Analysis"], ["57 use-cases (yet), ", "26", " LLMs (yet), n=10"], ["https://www.biorxiv.org/content/10.1101/2024.04.19.590278v3", " ", "https://github.com/haesleinhuepf/human-eval-bia/", "   "]]
# TRANSLATED:
#  [["Benchmarking LLMs für Bio-Bildanalyse"], ["57 Anwendungsfälle (bisher), ", "26", " LLMs (bisher), n=10"], ["https://www.biorxiv.org/content/10.1101/2024.04.19.590278v3", " ", "https://github.com/haesleinhuepf/human-eval-bia/", "   "]]
# ORIGINAL:
#  [[], ["Exercises", "Robert Haase"], [], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"]]
# TRANSLATED:
#  [[], ["Übungen", "Robert Haase"], [], ["CENTER FOR SCALABLE DATA ANALYTICS AND ARTIFICIAL INTELLIGENCE"]]
# ORIGINAL:
#  [["Exercises", ": Prompt Engineering Basics"], ["https://scads.github.io/prompt-engineering-basics-2024/10_prompting.html", " "], ["Copy prompt", "Paste ", "it", " ", "into", " ", "ChatGPT", "Read ", "response", "Repeat ;-)"]]
# TRANSLATED:
#  [["Übungen", ": Grundlagen des Prompt Engineering"], ["https://scads.github.io/prompt-engineering-basics-2024/10_prompting.html", " "], ["Eingabeaufforderung kopieren", "Einfügen ", "es", " ", "in", " ", "ChatGPT", "Antwort", "lesen ", "Wiederholen ;-)"]]
# ORIGINAL:
#  [["Exercises", ": ", "Prompting", " ", "basics", " (optional)"], ["https://scads.github.io/prompt-engineering-basics-2024/20_use_cases.html", " ", "https://scads.github.io/prompt-engineering-basics-2024/30_prompt_engineering.html", " "]]
# TRANSLATED:
#  [["Übungen", ": ", "Prompting", " ", "Grundlagen", " (optional)"], ["https://scads.github.io/prompt-engineering-basics-2024/20_use_cases.html", " ", "https://scads.github.io/prompt-engineering-basics-2024/30_prompt_engineering.html", " "]]
# ORIGINAL:
#  [["Exercises", ": Generative AI Notebooks"], ["Requires", " Python ", "programming", " ", "skills"], ["Installation ", "instructions", ";", "GPU-Workstation ", "recommended"], ["https://scads.github.io/generative-ai-notebooks/", " "]]
# TRANSLATED:
#  [["Übungen", ": Generative AI Notebooks"], ["Erfordert", " Python ", "Programmier", " ", "Kenntnisse"], ["Installations", "anweisungen", ";", "GPU-Workstation ", "empfohlen"], ["https://scads.github.io/generative-ai-notebooks/", " "]]
# ORIGINAL:
#  [["Exercise", ": ", "OpenAI", " API Key"], ["Create an ", "OpenAI", " API Key (", "usage", " ", "may", " ", "cost", " ", "money", ")"], ["https://openai.com/index/openai-api/", " "], ["1"], ["3"], ["2"], ["4"]]
# TRANSLATED:
#  [["Übung", ": ", "OpenAI", " API-Schlüssel"], ["Erstellen Sie einen ", "OpenAI", " API-Schlüssel (", "Nutzung", " ", "kann", " ", "Geld", " ", "kosten", ")"], ["https://openai.com/index/openai-api/", " "], ["1"], ["3"], ["2"], ["4"]]
# ORIGINAL:
#  [["Exercise: Store the API key in your environment"], ["Add the OPEN AI API Key to your environment variables"], ["1"], ["2"], ["3"], ["4"]]
# TRANSLATED:
#  [["Übung: Speichern Sie den API-Schlüssel in Ihrer Umgebung"], ["Fügen Sie den OPEN AI API-Schlüssel zu Ihren Umgebungsvariablen hinzu"], ["1"], ["2"], ["3"], ["4"]]
# ORIGINAL:
#  [["Exercise"], ["Alternatively, ", "zou", " can enter the OpenAI API-key like this at the beginning of notebooks:", "But do not share the key with others!"]]
# TRANSLATED:
#  [["Übung"], ["Alternativ, ", "könnten Sie", " den OpenAI API-Schlüssel am Anfang von Notizbüchern so eingeben:", "Aber teilen Sie den Schlüssel nicht mit anderen!"]]
# ORIGINAL:
#  [["Exercise", ": ", "ChatBots"], ["Modify ", "the", " ", "chatbot\u2018s", " internal ", "instructions", " ", "to", " ", "be", " ", "more", " ", "friendly"], ["https://scads.github.io/generative-ai-notebooks/20_chatbots/gui.html", " "]]
# TRANSLATED:
#  [["Übung", ": ", "ChatBots"], ["Ändern ", "die", " ", "internen", " ", "Anweisungen", " ", "des", " ", "Chatbot\u2018s", " ", "um", " ", "freundlicher", " ", "zu", " ", "sein"], ["https://scads.github.io/generative-ai-notebooks/20_chatbots/gui.html", " "]]
# ORIGINAL:
#  [["Learn more\u2026"], [], ["https://www.youtube.com/watch?v=9Y7f4j396hI", " "], ["https://www.youtube.com/watch?v=5sLYAQS9sWQ", " "], ["https://www.youtube.com/watch?v=9dtVlVwk2eg", " "]]
# TRANSLATED:
#  [["Erfahren Sie mehr\u2026"], [], ["https://www.youtube.com/watch?v=9Y7f4j396hI", " "], ["https://www.youtube.com/watch?v=5sLYAQS9sWQ", " "], ["https://www.youtube.com/watch?v=9dtVlVwk2eg", " "]]
# ORIGINAL:
#  [["Summary & outlook"], ["Transformers / LLMs disrupt work in couple of fields", "Text production", "Programming", "Prompt engineering becomes a key skill in many disciplines", "Multi-modal LLMs and multi-agent systems may bring next breakthroughs soon"], ["How many cells are there?"], ["There are 4 cells. I used this code\u2026"]]
# TRANSLATED:
#  [["Zusammenfassung & Ausblick"], ["Transformers / LLMs stören die Arbeit in einigen Bereichen", "Textproduktion", "Programmierung", "Prompt Engineering wird in vielen Disziplinen zu einer Schlüsselqualifikation", "Multi-modale LLMs und Multi-Agentensysteme könnten bald die nächsten Durchbrüche bringen"], ["Wie viele Zellen gibt es?"], ["Es gibt 4 Zellen. Ich habe diesen Code verwendet\u2026"]]
# ORIGINAL:
#  [["Acknowledgements"], ["Funding"], ["Communities & platforms"], ["Christian Tischer (EMBL Heidelberg)"], ["Nico Scherf ", "(MPI CBS Leipzig)"], ["Mara Lampert (ScaDS.AI / TU Dresden), Kevin Yamauchi  (ETH Zurich / Basel), Seth Hinz, Teun A.P.M. Huijben, ", "Jord\u00e3o", " Bragantini (CZ ", "Biohub", " San Francisco), llan Theodoro (CZ ", "Biohub", " and the State University of Campinas, Brazil), Ian C. (University of British Columbia)"], ["RH acknowledges the financial support by the Federal Ministry of Education and Research of Germany and by ", "S\u00e4chsische", " ", "Staatsministerium", " f\u00fcr ", "Wissenschaft", ", Kultur und ", "Tourismus", " in the ", "programme", " Center of Excellence for AI-research \u201eCenter for Scalable Data Analytics and Artificial Intelligence Dresden/Leipzig\u201c, project identification number: ScaDS.AI"], ["Jean-Karim ", "H\u00e9rich\u00e9", " (EMBL Heidelberg)"], ["Lo\u00efc", " A. Royer ", "(CZ ", "Biohub", ")"], ["http://doi.org/10.5281/zenodo.14796429", " "]]
# TRANSLATED:
#  [
#     ["Danksagungen"],
#     ["Finanzierung"],
#     ["Gemeinschaften & Plattformen"],
#     ["Christian Tischer (EMBL Heidelberg)"],
#     ["Nico Scherf ", "(MPI CBS Leipzig)"],
#     ["Mara Lampert (ScaDS.AI / TU Dresden), Kevin Yamauchi  (ETH Zurich / Basel), Seth Hinz, Teun A.P.M. Huijben, ", "Jordão", " Bragantini (CZ ", "Biohub", " San Francisco), llan Theodoro (CZ ", "Biohub", " and the State University of Campinas, Brazil), Ian C. (University of British Columbia)"],
#     ["RH erkennt die finanzielle Unterstützung durch das Bundesministerium für Bildung und Forschung Deutschlands und durch ", "Sächsische", " ", "Staatsministerium", " für ", "Wissenschaft", ", Kultur und ", "Tourismus", " im ", "Programm", " Exzellenzbereich für KI-Forschung „Center for Scalable Data Analytics and Artificial Intelligence Dresden/Leipzig“, Projektidentifikationsnummer: ScaDS.AI"],
#     ["Jean-Karim ", "Hériché", " (EMBL Heidelberg)"],
#     ["Loïc", " A. Royer ", "(CZ ", "Biohub", ")"],
#     ["http://doi.org/10.5281/zenodo.14796429", " "]
# ]

# %%
#with open('translated_text.json', 'w') as f:
#    json.dump(translated_texts, f, indent=2)

update_presentation(input_pptx, translated_texts, output_pptx)
# Out:
# Translating 'Large Language Models:' to 'Große Sprachmodelle:'
# Translating 'An Introduction' to 'Große Sprachmodelle:'
# Translating 'Robert Haase' to 'Große Sprachmodelle:'
# Translating 'These slides can be reused under the terms of the ' to 'Große Sprachmodelle:'
# Translating 'CC-BY4.0' to 'Eine Einführung'
# Translating ' license.' to 'Robert Haase'
# Translating 'Neural' to 'Neuronale'
# Translating 'networks' to 'Neuronale'
# Translating '   ' to ' '
# Translating 'Overview' to 'Übersicht'
# Translating 'engineering' to 'Engineering'
# Translating 'Function' to 'Funktions'
# Translating 'calling' to 'aufruf'
# Translating 'Agents' to 'Agenten'
# Translating 'translation' to 'Übersetzung'
# Translating 'English' to 'Englisch'
# Translating 'German' to 'Deutsch'
# Translating 'Neural' to 'Neuronales'
# Translating ' network (' to ' Netzwerk ('
# Translating 'simplified' to 'vereinfacht'
# Translating 'What are large language models good in?' to 'Worin sind große Sprachmodelle gut?'
# Translating 'Translation tasks' to 'Übersetzungsaufgaben'
# Translating 'Translating training materials' to 'Übersetzen von Trainingsmaterialien'
# Translating '“Please translate notebook ' to '„Bitte übersetzen Sie das Notebook '
# Translating ' to ' to ' in '
# Translating '<language>' to '<Sprache>'
# Translating '.”' to '.“'
# Translating 'https://github.com/haesleinhuepf/git-bob' to 'https://generated-books.github.io/'
# Translating 'https://github.com/haesleinhuepf/' to 'https://generated-books.github.io/'
# Translating 'bia' to ' '
# Translating '-bob' to 'https://github.com/haesleinhuepf/git-bob'
# Translating ' ' to 'https://github.com/haesleinhuepf/'
# Translating 'What are large language models good in?' to 'Wofür sind große Sprachmodelle gut?'
# Translating '• AI-generated ' to '• KI-generierte '
# Translating 'training materials' to 'Schulungsmaterialien'
# Translating 'https://haesleinhuepf.github.io/BioImageAnalysisNotebooks/' to 'https://scads.github.io/generative-ai-notebooks/'
# Translating ' ' to '  '
# Translating 'https://generated-books.github.io/' to 'https://scads.github.io/generative-ai-notebooks/'
# Translating ' ' to '  '
# Translating 'AI-based, automatic translation of training materials' to 'KI-basierte, automatische Übersetzung von Schulungsmaterialien'
# Translating 'AI-based, automatic generation of training materials' to 'KI-basierte, automatische Erstellung von Schulungsmaterialien'
# Translating 'Large Language Models' to 'Große Sprachmodelle'
# Translating 'Text-to-text, translation, ' to 'Text-zu-Text, Übersetzung, '
# Translating 'knowledge retrieval' to 'Wissensabruf'
# Translating 'Question' to 'Frage'
# Translating 'Answer' to 'Antwort'
# Translating 'Hallucinations' to 'Halluzinationen'
# Translating 'Large Language Models' to 'Große Sprachmodelle'
# Translating 'Text-to-text, translation, ' to 'Text-zu-Text, Übersetzung, '
# Translating 'reasoning' to 'Schlussfolgerung'
# Translating 'Hypothesis' to 'Hypothese'
# Translating 'Proof + Explanation' to 'Beweis + Erklärung'
# Translating 'Large Language Models' to 'Große Sprachmodelle'
# Translating 'Text-to-text, translation, ' to 'Text-zu-Text, Übersetzung, '
# Translating 'reasoning' to 'Schlussfolgerung'
# Translating 'Figure licensed ' to 'Abbildung lizenziert '
# Translating ' by Lu et al. ' to ' von Lu et al. '
# Translating 'https://arxiv.org/abs/2408.06292' to 'Abbildung lizenziert '
# Translating '  ' to 'CC-BY 4.0'
# Translating 'Large Language Models' to 'Große Sprachmodelle'
# Translating 'Text-to-text, translation, ' to 'Text-zu-Text, Übersetzung, '
# Translating 'code generation' to 'Code-Generierung'
# Translating 'image = ' to 'from skimage.io import '
# Translating '(“' to 'image = '
# Translating 'hela-cells.tif' to 'imread'
# Translating '”)' to '(“'
# Translating 'English' to 'Englisch'
# Translating 'Large Language Models' to 'Große Sprachmodelle'
# Translating 'Text-to-text, translation, ' to 'Text-zu-Text, Übersetzung, '
# Translating 'code generation' to 'Code-Generierung'
# Translating 'Source: Jimenez et al. (2024) licensed ' to 'Quelle: Jimenez et al. (2024) lizenziert '
# Translating 'https://arxiv.org/abs/2310.06770' to 'Quelle: Jimenez et al. (2024) lizenziert '
# Translating ' ' to 'CC-BY 4.0'
# Translating 'Large Language Models' to 'Große Sprachmodelle'
# Translating 'Text-to-text, translation, ' to 'Text-zu-Text, Übersetzung, '
# Translating 'code generation' to 'Code-Generierung'
# Translating 'https://github.com/haesleinhuepf/git-bob-playground/issues/48' to 'https://zenodo.org/records/14019030'
# Translating 'Why' to 'Warum'
# Translating 'code ' to 'Code-'
# Translating 'generation' to 'Generierung'
# Translating 'using' to 'mit'
# Translating 'Output of LLMs ' to 'Ausgabe von LLMs '
# Translating 'is' to 'wird'
# Translating 'often' to 'oft'
# Translating 'criticized' to 'kritisiert'
# Translating 'for' to 'für'
# Translating 'Limited ' to 'Ausgabe von LLMs '
# Translating 'reproducibility' to 'wird'
# Translating 'Hard ' to 'Ausgabe von LLMs '
# Translating 'to' to 'wird'
# Translating 'evaluate' to 'oft'
# Translating ' (' to ' '
# Translating 'automatically' to 'kritisiert'
# Translating ')' to ' '
# Translating 'Reproducible' to 'Output of LLM-'
# Translating 'Can ' to 'Output of LLM-'
# Translating 'be' to 'generated'
# Translating ' ' to ' code '
# Translating 'executed' to 'is'
# Translating ' and ' to 'Reproducible'
# Translating 'evaluted' to 'Can '
# Translating ' (' to 'be'
# Translating 'automatically' to ' '
# Translating ')' to 'executed'
# Translating 'Image Generation ' to 'Bildgenerierung '
# Translating 'a histology image of lung cancer cells and some healthy tissue' to 'ein histologisches Bild von Lungenkrebszellen und etwas gesundem Gewebe'
# Translating 'to' to 'zu'
# Translating '-image ' to '-Bild '
# Translating 'prompting' to 'Eingaben'
# Translating 'Interesting challenges for our community ahead' to 'Interessante Herausforderungen für unsere Gemeinschaft in der Zukunft'
# Translating 'New technologies bring new risks…' to 'Neue Technologien bringen neue Risiken…'
# Translating 'If you can generate images, ' to 'Wenn man Bilder generieren kann, '
# Translating 'you can also generate parts of images…. ' to 'kann man auch Teile von Bildern generieren…. '
# Translating 'Interesting challenges for our community ahead' to 'Interessante Herausforderungen für unsere Gemeinschaft voraus'
# Translating 'Langage' to 'Sprache'
# Translating ' Models ' to ' Modelle '
# Translating 'Combining image and text: ' to 'Kombinieren von Bild und Text: '
# Translating 'What’s in the blue-channel of this image?' to 'Was ist im Blaukanal dieses Bildes?'
# Translating 'There are nuclei, presumably stained with DAPI and imaged using a fluorescence microscope.' to 'Es gibt Kerne, vermutlich mit DAPI gefärbt und mit einem Fluoreszenzmikroskop aufgenommen.'
# Translating 'Combining image, text and […] data, to gain new insights.' to 'Kombinieren von Bild-, Text- und […] Daten, um neue Erkenntnisse zu gewinnen.'
# Translating 'How many cells are there?' to 'Wie viele Zellen gibt es?'
# Translating 'There are 4 cells. ' to 'Es gibt 4 Zellen. '
# Translating 'I just marked their nuclei.' to 'Ich habe gerade ihre Kerne markiert.'
# Translating 'I‘m' to 'Ich‘m'
# Translating ' not ' to ' nicht '
# Translating 'aware' to 'bewusst'
# Translating ' of ' to ' von '
# Translating 'any' to 'einer'
# Translating 'implementation' to 'Implementierung'
# Translating ' of ' to ' von '
# Translating 'this' to 'diesem'
# Translating 'yet' to 'noch'
# Translating ' neural networks' to ' neuronale Netzwerke'
# Translating '“Latent space”' to '“Bottleneck”, “Embedding”, '
# Translating 'Related' to 'LLMs '
# Translating ': Generative ' to 'use'
# Translating 'Pretrained' to ' '
# Translating ' ' to 'the'
# Translating 'Transformer' to ' '
# Translating ' (GPT)' to 'transformer'
# Translating 'were' to 'use'
# Translating 'originally' to 'the'
# Translating 'developed' to 'transformer'
# Translating 'for' to 'neural'
# Translating ' ' to ' network '
# Translating 'translation' to 'architecture'
# Translating ' ' to 'Related'
# Translating 'tasks' to ': Generative '
# Translating ' ' to 'Pretrained'
# Translating 'and ' to ' '
# Translating 'next-word' to 'Transformer'
# Translating ' ' to ' (GPT)'
# Translating 'prediction' to 'LLMs '
# Translating ':' to 'were'
# Translating 'Input' to 'Eingabe'
# Translating 'Output' to 'Ausgabe'
# Translating 'Output' to 'Ausgabe'
# Translating 'Masking' to 'Maskierung'
# Translating 'Microscope' to 'Mikroskop'
# Translating 'Generative ' to 'Generativ '
# Translating 'Cropped from ' to 'Ausgeschnitten von '
# Translating ' (2018), licensed ' to ' (2018), lizenziert '
# Translating 'Stacks of ' to 'Stapel von '
# Translating 'encoders' to 'Encodern'
# Translating ' and ' to ' und '
# Translating 'decoders' to 'Decodern'
# Translating 'arranged' to 'angeordnet'
# Translating ' like ' to ' wie '
# Translating 'this' to 'dies'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Vectors and matrices' to 'Vektoren und Matrizen'
# Translating 'Generative ' to 'Generativer '
# Translating 'Task: Translation' to 'Aufgabe: Übersetzung'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Example' to 'Beispiel'
# Translating 'input' to 'Eingabe'
# Translating 'Die ' to 'Beispiel'
# Translating 'Katze sitzt neben dem ' to ' '
# Translating 'Mikroskop' to 'Eingabe'
# Translating 'Example' to 'Beispiel'
# Translating 'output' to 'Ausgabe'
# Translating 'The ' to 'Beispiel'
# Translating 'cat' to ' '
# Translating ' ' to 'Ausgabe'
# Translating 'sits' to ':'
# Translating ' ' to 'The '
# Translating 'next' to 'cat'
# Translating 'to' to 'sits'
# Translating 'the' to 'next'
# Translating 'microscope' to 'to'
# Translating 'The: 0.9' to 'Next '
# Translating 'A: 0.1' to 'Next '
# Translating 'Generative ' to 'Generativ '
# Translating 'Task: Translation' to 'Aufgabe: Übersetzung'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Example' to 'Beispiel'
# Translating 'input' to 'Eingabe'
# Translating 'Die Katze' to 'Beispiel'
# Translating ' sitzt neben dem ' to ' '
# Translating 'Mikroskop' to 'Eingabe'
# Translating 'Example' to 'Beispiel'
# Translating 'output' to 'Ausgabe'
# Translating 'The' to 'Beispiel'
# Translating 'cat' to 'Ausgabe'
# Translating ' ' to ':'
# Translating 'sits' to 'The'
# Translating 'next' to 'cat'
# Translating 'to' to 'sits'
# Translating 'the' to 'next'
# Translating 'microscope' to 'to'
# Translating 'cat' to 'Next '
# Translating ': 0.9' to 'word'
# Translating 'dog' to 'Next '
# Translating ': 0.0001' to 'word'
# Translating 'Task: Translation' to 'Aufgabe: Übersetzung'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Example' to 'Beispiel'
# Translating 'input' to 'Eingabe'
# Translating 'Die Katze' to 'Beispiel'
# Translating 'sitzt' to 'Eingabe'
# Translating ' neben dem ' to ':'
# Translating 'Mikroskop' to 'Die Katze'
# Translating 'Example' to 'Beispiel'
# Translating 'output' to 'Ausgabe'
# Translating 'The' to 'Beispiel'
# Translating 'cat' to 'Ausgabe'
# Translating ' ' to ':'
# Translating 'sits' to 'The'
# Translating 'next' to 'cat'
# Translating 'to' to 'sits'
# Translating 'the' to 'next'
# Translating 'microscope' to 'to'
# Translating 'Next ' to 'Nächste '
# Translating 'word' to 'Wort'
# Translating 'probabilities' to 'Wahrscheinlichkeiten'
# Translating 'according' to 'gemäß'
# Translating 'to' to 'dem'
# Translating 'context' to 'Kontext'
# Translating 'sits' to 'Nächste '
# Translating ': 0.8' to 'Wort'
# Translating 'takes' to 'Nächste '
# Translating ' a ' to 'Wort'
# Translating 'seat' to ' '
# Translating ': 0.2' to 'Wahrscheinlichkeiten'
# Translating 'Generative ' to 'Generativ '
# Translating 'Pretrained' to 'vorgeschult'
# Translating 'Task: Translation' to 'Aufgabe: Übersetzung'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Example' to 'Beispiel'
# Translating 'input' to 'Eingabe'
# Translating 'Die Katze' to 'Beispiel'
# Translating 'sitzt' to 'Eingabe'
# Translating ' ' to ':'
# Translating 'neben' to 'Die Katze'
# Translating ' dem ' to ' '
# Translating 'Mikroskop' to 'sitzt'
# Translating 'Example' to 'Beispiel'
# Translating 'output' to 'Ausgabe'
# Translating 'The' to 'Beispiel'
# Translating 'cat' to 'Ausgabe'
# Translating ' ' to ':'
# Translating 'sits' to 'The'
# Translating 'next' to 'cat'
# Translating 'to' to 'sits'
# Translating 'the' to 'next'
# Translating 'microscope' to 'to'
# Translating 'next' to 'Next '
# Translating ' ' to 'word'
# Translating 'to' to ' '
# Translating ': 0.6' to 'probabilities'
# Translating 'near' to 'Next '
# Translating ': 0.4' to 'word'
# Translating 'Generative ' to 'Generativ '
# Translating 'Task: Translation' to 'Aufgabe: Übersetzung'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Example' to 'Beispiel'
# Translating 'input' to 'Eingabe'
# Translating 'Die Katze' to 'Beispiel'
# Translating 'sitzt' to 'Eingabe'
# Translating ' ' to ':'
# Translating 'neben' to 'Die Katze'
# Translating 'dem' to 'sitzt'
# Translating 'Mikroskop' to 'neben'
# Translating 'The' to 'Example'
# Translating 'cat' to 'output'
# Translating ' ' to ':'
# Translating 'sits' to 'The'
# Translating 'next' to 'cat'
# Translating 'to' to 'sits'
# Translating 'the' to 'next'
# Translating 'microscope' to 'to'
# Translating 'the' to 'Next '
# Translating ': 0.9' to 'word'
# Translating 'a: 0.1' to 'Next '
# Translating 'Task: Translation' to 'Aufgabe: Übersetzung'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Example' to 'Beispiel'
# Translating 'input' to 'Eingabe'
# Translating 'Die Katze' to 'Beispiel'
# Translating 'sitzt' to 'Eingabe'
# Translating ' ' to ':'
# Translating 'neben' to 'Die Katze'
# Translating 'dem' to 'sitzt'
# Translating 'Mikroskop' to 'neben'
# Translating 'Example' to 'Beispiel'
# Translating 'output' to 'Ausgabe'
# Translating 'The' to 'Beispiel'
# Translating 'cat' to 'Ausgabe'
# Translating ' ' to ':'
# Translating 'sits' to 'The'
# Translating 'next' to 'cat'
# Translating 'to' to 'sits'
# Translating 'the' to 'next'
# Translating 'microscope' to 'to'
# Translating 'Heating' to 'Next '
# Translating ': 0.9' to 'word'
# Translating 'Food: 0.8' to 'Next '
# Translating 'Dog: 0.2' to 'Next '
# Translating 'Microscope' to 'Next '
# Translating ': 0.01' to 'word'
# Translating 'Generative ' to 'Generativer '
# Translating 'Pretrained' to 'Pretrainierter'
# Translating 'Task: Translation' to 'Aufgabe: Übersetzung'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Example' to 'Beispiel'
# Translating 'input' to 'Eingabe'
# Translating 'Die Katze sitzt neben dem ' to 'Beispiel'
# Translating 'Mikroskop' to ' '
# Translating 'The ' to 'Example'
# Translating 'cat' to ' '
# Translating ' ' to 'output'
# Translating 'sits' to ':'
# Translating ' ' to 'The '
# Translating 'next' to 'cat'
# Translating 'to' to 'sits'
# Translating 'the' to 'next'
# Translating 'microscope' to 'to'
# Translating 'Heating' to 'Next '
# Translating ': 0.9' to 'word'
# Translating 'Food: 0.8' to 'Next '
# Translating 'Dog: 0.2' to 'Next '
# Translating 'Microscope' to 'Next '
# Translating ': 0.01' to 'word'
# Translating 'Microscope' to 'Mikroskop'
# Translating 'Through training / fine-tuning, you can increase the probabilities of words. ' to 'Durch Training / Feinabstimmung können Sie die Wahrscheinlichkeiten von Wörtern erhöhen.'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Word Embedding ' to 'Wort-Einbettung '
# Translating 'Figure source: Vaswani et al (2017)' to 'Bildquelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Bildquelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Next ' to 'The '
# Translating 'to' to 'cat'
# Translating 'the' to 'sits'
# Translating 'microscope' to 'next'
# Translating 'there' to 'to'
# Translating ' ' to ' a '
# Translating 'is' to 'microscope'
# Translating ' a ' to '.'
# Translating 'cat' to 'Next '
# Translating '.' to 'to'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Scaled' to 'Skalierte'
# Translating 'attention' to 'Aufmerksamkeit'
# Translating 'Query' to 'Attention score: '
# Translating ': ' to 'How'
# Translating 'For' to ' '
# Translating ' ' to 'much'
# Translating 'which' to ' '
# Translating ' ' to 'related'
# Translating 'word' to ' '
# Translating ' are we calculating attention?' to 'are'
# Translating 'Key' to 'Attention score: '
# Translating ': To which word are we calculating attention' to 'How'
# Translating 'Value: Relevance ' to 'Attention score: '
# Translating 'of the query-key relationship ' to 'How'
# Translating 'The ' to 'Attention score: '
# Translating 'cat' to 'How'
# Translating 'is' to 'much'
# Translating 'black' to 'related'
# Translating ' and ' to ' '
# Translating 'white' to 'are'
# Translating '.' to ' '
# Translating 'The ' to 'Attention score: '
# Translating 'cat' to 'How'
# Translating 'is' to 'much'
# Translating 'meowing' to 'related'
# Translating '.' to ' '
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'See also: ' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://www.youtube.com/watch?v=sznZ78HquPc' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Relevance' to 'Relevanz'
# Translating 'value' to 'wert'
# Translating 'Relevance' to 'Relevanz'
# Translating 'value' to 'wert'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'head' to 'Head'
# Translating 'attentions' to 'Aufmerksamkeiten'
# Translating 'Multiple ' to 'Mehrere '
# Translating 'aspects' to 'Aspekte'
# Translating 'represented' to 'dargestellt'
# Translating 'by' to 'durch'
# Translating ' multiple ' to ' mehrere '
# Translating 'attention' to 'Aufmerksamkeits'
# Translating 'heads' to 'Köpfe'
# Translating 'Source Figure left/right: ' to 'Quelle Abbildung links/rechts: '
# Translating ' (2018), licensed ' to ' (2018), lizenziert '
# Translating 'Source Figure center: Vaswani et al (2017)' to 'Quelle Abbildung links/rechts: '
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle Abbildung links/rechts: '
# Translating ' ' to 'Alammar'
# Translating 'Source: Vaswani et al (2017)' to 'Quelle: Vaswani et al (2017)'
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle: Vaswani et al (2017)'
# Translating ' ' to 'https://arxiv.org/abs/1706.03762'
# Translating 'Source Figure right: ' to 'Quelle Abbildung rechts: '
# Translating ' (2018), licensed ' to ' (2018), lizenziert '
# Translating 'Source Figure left: Vaswani et al (2017)' to 'Quelle Abbildung rechts: '
# Translating 'https://arxiv.org/abs/1706.03762' to 'Quelle Abbildung rechts: '
# Translating ' ' to 'Alammar'
# Translating 'Summary' to 'Zusammenfassung'
# Translating 'The ' to 'Die '
# Translating 'cat' to 'Katze'
# Translating 'is' to 'ist'
# Translating 'black' to 'schwarz'
# Translating ' and ' to ' und '
# Translating 'white' to 'weiß'
# Translating 'The ' to 'Die '
# Translating 'cat' to 'Katze'
# Translating 'is' to 'ist'
# Translating 'meowing' to 'schwarz'
# Translating '.' to ' und '
# Translating 'Relevance' to 'Relevanz'
# Translating 'Relevance' to 'Relevanz'
# Translating 'What are large language models ' to 'Worin sind große Sprachmodelle '
# Translating 'not so good ' to 'nicht so gut '
# Translating 'in?' to '?'
# Translating 'Querying knowledge (e.g. for recent information)' to 'Abfragen von Wissen (z.B. für aktuelle Informationen)'
# Translating 'Related' to 'LLMs '
# Translating ': Generative ' to 'use'
# Translating 'Pretrained' to ' '
# Translating ' ' to 'the'
# Translating 'Transformer' to ' '
# Translating ' (GPT)' to 'transformer'
# Translating 'were' to 'use'
# Translating 'originally' to 'the'
# Translating 'developed' to 'transformer'
# Translating 'for' to 'neural'
# Translating ' ' to ' network '
# Translating 'translation' to 'architecture'
# Translating ' ' to 'Related'
# Translating 'tasks' to ': Generative '
# Translating ' ' to 'Pretrained'
# Translating 'and ' to ' '
# Translating 'next-word' to 'Transformer'
# Translating ' ' to ' (GPT)'
# Translating 'prediction' to 'LLMs '
# Translating ':' to 'were'
# Translating 'Input' to 'Eingabe'
# Translating 'Output' to 'Ausgabe'
# Translating 'Output' to 'Ausgabe'
# Translating 'Masking' to 'Maskierung'
# Translating 'Microscope' to 'Mikroskop'
# Translating 'use' to 'verwenden'
# Translating 'combinations' to 'Kombinationen'
# Translating ' of traditional ' to ' aus traditionellen '
# Translating 'neural' to 'neuronalen'
# Translating ' network ' to ' Netzwerk-'
# Translating 'architectures' to 'Architekturen'
# Translating ' and  ' to ' und  '
# Translating 'transformers' to 'Transformatoren'
# Translating 'Output' to 'Ausgabe'
# Translating 'Output' to 'Ausgabe'
# Translating 'Masking' to 'Maskierung'
# Translating 'Microscope' to 'Mikroskop'
# Translating '“Embedding”, ' to '„Einbettung“, '
# Translating '“Latent space”' to '„Einbettung“, '
# Translating 'Input' to 'Eingabe'
# Translating 'Use ' to 'Verwendungs'
# Translating 'case' to 'zweck'
# Translating 'Descriptive' to 'Deskriptive'
# Translating 'biology' to 'Biologie'
# Translating 'Cropped from Paci & ' to 'Ausgeschnitten von Paci & '
# Translating ' (2024), licensed ' to ' (2024), lizenziert '
# Translating 'https://www.biorxiv.org/content/10.1101/2024.05.27.594652v1' to 'Ausgeschnitten von Paci & '
# Translating ' ' to 'Nanni'
# Translating '“… while ' to '“… während '
# Translating 'visual language models ' to 'visuelle Sprachmodelle '
# Translating 'are in their infancy, they already show potential for multiple applications in automated phenotyping studies. We encourage the community to carefully test them… “' to 'sich noch in den Kinderschuhen befinden, zeigen sie bereits Potenzial für mehrere Anwendungen in automatisierten Phänotypisierungsstudien. Wir ermutigen die Gemeinschaft, sie sorgfältig zu testen… “'
# Translating 'Prompt Engineering' to 'Prompt-Engineering'
# Translating 'NATIONAL RESEARCH DATA MANAGEMENT INFRASTRUCTURE FOR MICROSCOPY AND BIOIMAGE ANALYSIS' to 'NATIONALE FORSCHUNGSDATEN-INFRASTRUKTUR FÜR MIKROSKOPIE UND BIOBILDANALYSE'
# Translating 'Long-context prompting' to 'Lang-Kontext-Aufforderung'
# Translating 'Also known as ' to 'Auch bekannt als '
# Translating 'Context with plenty of knowledge provided in system message' to 'Auch bekannt als '
# Translating 'User‘s query' to 'Benutzeranfrage‘'
# Translating 'Prompt Engineering' to 'Promptgestaltung'
# Translating 'Response' to 'Antwort'
# Translating 'System message (1000s of tokens)' to 'Systemnachricht (1000e von Tokens)'
# Translating 'Modify a prompt ' to 'Modifizieren Sie einen Prompt '
# Translating 'until' to 'bis'
# Translating 'it' to 'er'
# Translating 'works' to 'funktioniert'
# Translating 'Set context / assign role' to 'Modifizieren Sie einen Prompt '
# Translating 'Define output style' to 'Modifizieren Sie einen Prompt '
# Translating 'Give hints / conditions' to 'Modifizieren Sie einen Prompt '
# Translating 'List tasks' to 'Modifizieren Sie einen Prompt '
# Translating 'Provide data' to 'Modifizieren Sie einen Prompt '
# Translating 'Modify a prompt ' to 'Modifizieren Sie einen Prompt '
# Translating 'until' to 'bis'
# Translating 'it' to 'es'
# Translating 'works' to 'funktioniert'
# Translating 'Set context / assign role' to 'Modifizieren Sie einen Prompt '
# Translating 'Define output style' to 'Modifizieren Sie einen Prompt '
# Translating 'Give hints / conditions' to 'Modifizieren Sie einen Prompt '
# Translating 'List tasks' to 'Modifizieren Sie einen Prompt '
# Translating 'Provide data' to 'Modifizieren Sie einen Prompt '
# Translating 'Modify a prompt ' to 'Ändere einen Prompt '
# Translating 'until' to 'bis'
# Translating 'it' to 'er'
# Translating 'works' to 'funktioniert'
# Translating 'Set context / assign role' to 'Ändere einen Prompt '
# Translating 'Define output style' to 'Ändere einen Prompt '
# Translating 'Give hints / conditions' to 'Ändere einen Prompt '
# Translating 'List tasks' to 'Ändere einen Prompt '
# Translating 'Provide data' to 'Ändere einen Prompt '
# Translating 'Visualization by Greg ' to 'Visualisierung von Greg '
# Translating ', Licensed MIT (modified), Source: ' to ', Lizenz MIT (modifiziert), Quelle: '
# Translating 'Prompt engineering' to 'Prompt-Engineering'
# Translating 'Visualization by Greg ' to 'Visualisierung von Greg '
# Translating ', Licensed MIT (modified), Source: ' to ', Lizenz MIT (geändert), Quelle: '
# Translating 'Prompt engineering' to 'Prompt-Engineering'
# Translating 'Prompt Engineering' to 'Prompt-Engineering'
# Translating 'Modify a prompt ' to 'Modifizieren Sie einen Prompt '
# Translating 'until' to 'bis'
# Translating 'it' to 'es'
# Translating 'works' to 'funktioniert'
# Translating 'Write python code to open the image file 'data/' to 'Modifizieren Sie einen Prompt '
# Translating 'blobs.tif' to 'bis'
# Translating '' ' to ' '
# Translating 'and threshold it using Otsu's method.' to 'Modifizieren Sie einen Prompt '
# Translating 'Apply connected component labeling to the result to ' to 'Modifizieren Sie einen Prompt '
# Translating 'retrieve a label image. Visualize the label image.' to 'Modifizieren Sie einen Prompt '
# Translating 'Prompt Engineering' to 'Prompttechnik'
# Translating 'Modify a prompt ' to 'Modifizieren Sie ein Ausgangsaufforderung '
# Translating 'until' to 'bis'
# Translating 'it' to 'es'
# Translating 'works' to 'funktioniert'
# Translating 'Write python code to open the image file 'data/' to 'Modifizieren Sie ein Ausgangsaufforderung '
# Translating 'blobs.tif' to 'bis'
# Translating '' ' to ' '
# Translating 'and threshold it using Otsu's method.' to 'Modifizieren Sie ein Ausgangsaufforderung '
# Translating 'Apply connected component labeling to the result to ' to 'Modifizieren Sie ein Ausgangsaufforderung '
# Translating 'retrieve a label image. Visualize the label image.' to 'Modifizieren Sie ein Ausgangsaufforderung '
# Translating 'Do not explain the solution. ' to 'Modifizieren Sie ein Ausgangsaufforderung '
# Translating 'Only write Python code and short comments are ok.' to 'Modifizieren Sie ein Ausgangsaufforderung '
# Translating 'Prompt Engineering' to 'Prompt-Engineering'
# Translating 'Write python code to open the image file 'data/' to 'Modify a prompt '
# Translating 'blobs.tif' to 'until'
# Translating '' ' to ' '
# Translating 'and threshold it using Otsu's method.' to 'Modify a prompt '
# Translating 'Apply connected component labeling to the result to ' to 'Modify a prompt '
# Translating 'retrieve a label image. Visualize the label image.' to 'Modify a prompt '
# Translating 'Do not explain the solution. ' to 'Modify a prompt '
# Translating 'Only write Python code and short comments are ok.' to 'Modify a prompt '
# Translating 'Assume the code is executed in a ' to 'Modify a prompt '
# Translating 'Jupyter' to 'until'
# Translating ' notebook.' to ' '
# Translating 'Do not use any of these Python libraries:' to 'Modify a prompt '
# Translating '* OpenCV' to 'Modify a prompt '
# Translating '* PIL' to 'Modify a prompt '
# Translating '* Pillow' to 'Modify a prompt '
# Translating '„Long“ ' to '„Langer“ '
# Translating 'Context' to 'Kontext'
# Translating 'Scientific code writing: ' to 'Wissenschaftliches Schreiben von Code: '
# Translating 'After learning ' to 'Nach dem Lernen '
# Translating 'how to prompt' to 'wie man anleitet'
# Translating ' for code: try more complex workflows' to ' für Code: versuche komplexere Workflows'
# Translating 'Including ' to 'Einschließlich '
# Translating 'scientist' to 'Computer'
# Translating 'That makes sense!' to 'Das ergibt Sinn!'
# Translating 'Biologist' to 'Biologe'
# Translating 'That’s right!' to 'Das ist richtig!'
# Translating 'Including ' to 'Einschließlich '
# Translating ' language models (VLMs)' to ' Sprachmodellen (VLMs)'
# Translating 'scientist' to 'Computer'
# Translating 'Biologist' to 'Biologe'
# Translating 'To' to 'Um'
# Translating 'proof-read' to 'diesen'
# Translating ' ' to ' Code '
# Translating 'this' to 'Korrektur zu lesen'
# Translating ' code, ' to ', '
# Translating 'you' to 'benötigen'
# Translating 'need' to 'Sie'
# Translating 'programming' to 'Programmier'
# Translating 'skills' to 'kenntnisse'
# Translating 'Generating ' to 'Erstellen von '
# Translating 'using' to 'mithilfe'
# Translating 'Ask %%' to 'Bitte %%'
# Translating 'to' to 'dazu'
# Translating ' ' to ', '
# Translating 'generate' to 'ein '
# Translating ' a ' to 'Jupyter'
# Translating 'Jupyter' to ' '
# Translating ' ' to 'notebook'
# Translating 'notebook' to ' zu erstellen'
# Translating 'Present' to 'Präsentiere'
# Translating ' Bob an ' to ' Bob ein '
# Translating 'image' to 'Bild'
# Translating ' like ' to ' wie '
# Translating 'this' to 'dieses'
# Translating 'Generating ' to 'Generieren '
# Translating 'notebooks' to 'von Notizbüchern'
# Translating 'using' to 'mit'
# Translating 'vision' to 'Vision'
# Translating 'models' to 'Modellen'
# Translating 'AI agents & function calling' to 'KI-Agenten & Funktionsaufruf'
# Translating 'NATIONAL RESEARCH DATA MANAGEMENT INFRASTRUCTURE FOR MICROSCOPY AND BIOIMAGE ANALYSIS' to 'NATIONALE FORSCHUNGSDATENINFRASTRUKTUR FÜR MIKROSKOPIE UND BIOBILDANALYSE'
# Translating 'Function' to 'Funktion'
# Translating ' Calling: 1. ' to ' Aufruf: 1. '
# Translating 'choosing' to 'Auswahl'
# Translating ' a ' to ' einer '
# Translating 'function' to 'Funktion'
# Translating 'Given a list of ' to 'Gegeben eine Liste von '
# Translating 'tools' to 'Tools'
# Translating 'get_current_time' to 'Gegeben eine Liste von '
# Translating 'order_food' to 'Gegeben eine Liste von '
# Translating 'book_room' to 'Gegeben eine Liste von '
# Translating '… and a ' to 'Gegeben eine Liste von '
# Translating 'task' to 'Tools'
# Translating ':' to '…'
# Translating 'Please' to 'Gegeben eine Liste von '
# Translating ' ' to 'Tools'
# Translating 'book' to '…'
# Translating ' ' to 'get_current_time'
# Translating 'meeting' to 'order_food'
# Translating ' ' to 'book_room'
# Translating 'room' to '… und eine '
# Translating ' 3 ' to 'Aufgabe'
# Translating 'for' to ':'
# Translating ' Robert at 3pm.' to 'Bitte'
# Translating 'Which' to 'Gegeben eine Liste von '
# Translating ' ' to 'Tools'
# Translating 'is' to '…'
# Translating ' ' to 'get_current_time'
# Translating 'the' to 'order_food'
# Translating ' ' to 'book_room'
# Translating 'right' to '… und eine '
# Translating ' ' to 'Aufgabe'
# Translating 'tool' to ':'
# Translating ' ' to 'Bitte'
# Translating 'to' to ' '
# Translating ' ' to 'buche'
# Translating 'use' to ' '
# Translating '?' to 'Meeting'
# Translating 'Some' to 'Eine'
# Translating 'kind' to 'Art'
# Translating ' of ' to ' von '
# Translating 'next-word' to 'Next-Word'
# Translating 'prediction' to 'Vorhersage'
# Translating 'task' to 'Aufgabe'
# Translating 'Function' to 'Funktion'
# Translating 'calling' to 'aufrufen'
# Translating 'parameterizing' to 'parametrieren'
# Translating 'book_room' to 'Given a '
# Translating '(' to 'function'
# Translating 'room' to ' '
# Translating ', time, ' to 'signature'
# Translating 'person' to '…'
# Translating ')' to 'book_room'
# Translating '… and a ' to 'Given a '
# Translating 'task' to 'function'
# Translating ':' to ' '
# Translating 'Please' to 'Given a '
# Translating ' ' to 'function'
# Translating 'book' to ' '
# Translating ' ' to 'signature'
# Translating 'meeting' to '…'
# Translating ' ' to 'book_room'
# Translating 'room' to '('
# Translating ' 3 ' to 'room'
# Translating 'for' to ', time, '
# Translating ' Robert at 3pm.' to 'person'
# Translating 'How' to 'Given a '
# Translating ' ' to 'function'
# Translating 'could' to ' '
# Translating ' I ' to 'signature'
# Translating 'use' to '…'
# Translating ' ' to 'book_room'
# Translating 'the' to '('
# Translating ' ' to 'room'
# Translating 'tool' to ', time, '
# Translating '?' to 'person'
# Translating 'Some' to 'Eine'
# Translating 'kind' to 'Art'
# Translating ' of ' to ' von '
# Translating 'translation' to 'Übersetzungs'
# Translating 'task' to 'Aufgabe'
# Translating 'Function' to 'Funktion'
# Translating 'calling' to 'aufrufen'
# Translating 'parameterizing' to 'parametrisieren'
# Translating 'book_room' to 'Given a '
# Translating '(' to 'function'
# Translating 'room' to ' '
# Translating ', time, ' to 'signature'
# Translating 'person' to '…'
# Translating ')' to 'book_room'
# Translating '… and a ' to 'Given a '
# Translating 'task' to 'function'
# Translating ':' to ' '
# Translating 'Please' to 'Given a '
# Translating ' ' to 'function'
# Translating 'book' to ' '
# Translating ' ' to 'signature'
# Translating 'meeting' to '…'
# Translating ' ' to 'book_room'
# Translating 'room' to '('
# Translating ' 3 ' to 'room'
# Translating 'for' to ', time, '
# Translating ' Robert at 3pm.' to 'person'
# Translating 'How' to 'Given a '
# Translating ' ' to 'function'
# Translating 'could' to ' '
# Translating ' I ' to 'signature'
# Translating 'use' to '…'
# Translating ' ' to 'book_room'
# Translating 'the' to '('
# Translating ' ' to 'room'
# Translating 'tool' to ', time, '
# Translating '?' to 'person'
# Translating 'LLMs controlling program flow' to 'LLMs zur Steuerung des Programmablaufs'
# Translating 'Function calling for bio-image analysis' to 'Funktionsaufruf für die Bio-Bildanalyse'
# Translating 'Agents ' to 'Agenten '
# Translating '[computer program] that represents a legal entity (e.g. a person)' to 'Agent:'
# Translating 'can ' to 'Agent:'
# Translating 'interact with the world ' to '[Computersystem] das eine juristische Person repräsentiert (z.B. eine Person)'
# Translating 'on behalf' to 'kann '
# Translating ' ' to 'mit der Welt interagieren '
# Translating 'of them' to 'im Namen'
# Translating 'LLM-based agent:' to 'Agent:'
# Translating 'Control flow of a program based on an LLM' to 'Agent:'
# Translating 'The LLM ' to 'Agent:'
# Translating 'decides' to '[Computersystem] das eine juristische Person repräsentiert (z.B. eine Person)'
# Translating ' what action to execution, ' to 'kann '
# Translating 'what function to call' to 'mit der Welt interagieren '
# Translating 'Agents: Customer support' to 'Agenten: Kundensupport'
# Translating 'representing a seller' to 'der einen Verkäufer repräsentiert'
# Translating ' communicates with customer on their behalf.' to ' kommuniziert im Namen des Verkäufers mit dem Kunden.'
# Translating 'User' to 'Benutzer'
# Translating 'Online store' to 'Online-Shop'
# Translating 'When will my order arrive?' to 'Wann wird meine Bestellung eintreffen?'
# Translating '‘Friday’' to '‘Freitag’'
# Translating 'Store owner is responsible' to 'Geschäftsinhaber ist verantwortlich'
# Translating 'Function calling / “tool calling”' to 'Funktionsaufruf / „Toolaufruf“'
# Translating 'Enabling LLMs to interact with the world' to 'LLMs ermöglichen, mit der Welt zu interagieren'
# Translating 'Prompt Engineering' to 'Prompt-Engineering'
# Translating 'Prompt Engineering' to 'Prompt-Engineering'
# Translating 'Function call' to 'Funktionsaufruf'
# Translating 'Execution result' to 'Ausführungsergebnis'
# Translating 'Developer / service providers are responsible' to 'Entwickler / Dienstanbieter sind verantwortlich'
# Translating 'User‘s query' to 'Benutzeranfrage'
# Translating 'Response' to 'Antwort'
# Translating 'Agents: Shopping assistant' to 'Agenten: Einkaufsassistent'
# Translating 'representing a customer ' to 'der einen Kunden vertritt '
# Translating 'buys a product, e.g. in an online store, calling a store application programming interface (API).' to 'kauft ein Produkt, z.B. in einem Online-Shop über eine Store-Anwendungsprogrammierschnittstelle (API).'
# Translating 'User' to 'Benutzer'
# Translating 'Online store' to 'Online-Shop'
# Translating '“Order Salami Pizza!”' to '“Bestelle Salami-Pizza!”'
# Translating 'Customer is responsible' to 'Kunde ist verantwortlich'
# Translating 'Function calling / “tool calling”' to 'Funktionsaufruf / „Werkzeugaufruf“'
# Translating 'Enabling LLMs to interact with the world' to 'Aktivierung von LLMs zur Interaktion mit der Welt'
# Translating 'Prompt Engineering' to 'Prompt-Engineering'
# Translating 'Prompt Engineering' to 'Prompt-Engineering'
# Translating 'Function call' to 'Funktionsaufruf'
# Translating 'Execution result' to 'Ausführungsergebnis'
# Translating 'User is responsible' to 'Benutzer ist verantwortlich'
# Translating 'User‘s query' to 'Anfrage des Benutzers'
# Translating 'Response' to 'Antwort'
# Translating 'Limits of agents' to 'Grenzen von Agenten'
# Translating 'An LLM control the program flow -> LLM outputs are ' to 'Ein LLM steuert den Programmfluss -> LLM-Ausgaben sind '
# Translating 'non-deterministic' to 'nicht-deterministisch'
# Translating 'Long [internal] chat history confuses tool-selection.' to 'Ein LLM steuert den Programmfluss -> LLM-Ausgaben sind '
# Translating 'Agents with too many diverse tools tend to act confused. ' to 'Ein LLM steuert den Programmfluss -> LLM-Ausgaben sind '
# Translating 'Multi-talent agent' to 'Vielseitigkeitsagent'
# Translating 'Can: ' to 'Kann: '
# Translating 'Read abstracts' to 'Kann: '
# Translating 'Summarize papers' to 'Kann: '
# Translating 'Provide feedback' to 'Kann: '
# Translating 'Write papers' to 'Kann: '
# Translating 'Incorporate feedback' to 'Kann: '
# Translating 'Print the final paper' to 'Kann: '
# Translating 'Multi-agent systems' to 'Multi-Agenten-Systeme'
# Translating 'Multiple agents with ' to 'Mehrere Agenten mit '
# Translating 'different specialities' to 'Mehrere Agenten mit '
# Translating 'Independent memory (inner chat history)' to 'Mehrere Agenten mit '
# Translating 'Scheduler agent distributes tasks' to 'Mehrere Agenten mit '
# Translating 'Research assistant' to 'Forschungsassistent'
# Translating 'Can: ' to 'Kann: '
# Translating 'Read ' to 'Kann: '
# Translating 'arxiv' to 'Liest '
# Translating ' abstracts' to 'arxiv'
# Translating 'Science writer' to 'Wissenschaftsautor'
# Translating 'Can: ' to 'Kann: '
# Translating 'Write papers' to 'Kann: '
# Translating 'Incorporate feedback' to 'Kann: '
# Translating 'Reviewer' to 'Rezensent'
# Translating 'Can: ' to 'Kann: '
# Translating 'Read text' to 'Kann: '
# Translating 'Provide feedback' to 'Kann: '
# Translating 'Scheduler agent' to 'Scheduler-Agent'
# Translating 'Can: ' to 'Kann: '
# Translating 'Split complex tasks in sub-tasks' to 'Kann: '
# Translating 'Distribute tasks' to 'Kann: '
# Translating 'Printer' to 'Drucker'
# Translating 'Manuscript' to 'Manuskript'
# Translating 'Example: Summarizing ' to 'Beispiel: Zusammenfassen '
# Translating '-Papers' to '-Papiere'
# Translating 'Task: Read 5 ' to 'Aufgabe: Lesen Sie 5 '
# Translating ' papers and write a review about them' to ' Papiere und schreiben Sie eine Rezension darüber'
# Translating 'Example: Summarizing ' to 'Beispiel: Zusammenfassen '
# Translating '-Papers' to '-Papieren'
# Translating 'Task: Read 5 ' to 'Aufgabe: Lesen Sie 5 '
# Translating ' papers and write a review about them' to ' Papiere und schreiben Sie eine Rezension darüber'
# Translating 'Scheduler needs this information to decide about which agent can do which tasks' to 'Der Scheduler benötigt diese Informationen, um zu entscheiden, welcher Agent welche Aufgaben übernehmen kann'
# Translating 'The ' to 'Das '
# Translating ' framework needs this information to set parameters accordingly' to '-Framework benötigt diese Informationen, um die Parameter entsprechend festzulegen'
# Translating 'Research assistant' to 'Forschungsassistent'
# Translating 'Can: ' to 'Kann: '
# Translating 'Read ' to 'Kann: '
# Translating 'arxiv' to 'Lesen '
# Translating ' abstracts' to 'arxiv'
# Translating 'Example: Summarizing ' to 'Beispiel: Zusammenfassen von '
# Translating '-Papers' to '-Papieren'
# Translating 'Task: Read 5 ' to 'Aufgabe: Lies 5 '
# Translating ' papers and write a review about them' to ' Papiere und schreibe eine Rezension darüber'
# Translating 'Science writer' to 'Wissenschaftsautor'
# Translating 'Can: ' to 'Kann: '
# Translating 'Write papers' to 'Kann: '
# Translating 'Incorporate feedback' to 'Kann: '
# Translating 'Example: Summarizing ' to 'Beispiel: Zusammenfassen von '
# Translating '-Papers' to '-Papieren'
# Translating 'Task: Read 5 ' to 'Aufgabe: 5 '
# Translating ' papers and write a review about them' to ' Papiere lesen und eine Rezension darüber schreiben'
# Translating 'Reviewer' to 'Rezensent'
# Translating 'Can: ' to 'Kann: '
# Translating 'Read text' to 'Kann: '
# Translating 'Provide feedback' to 'Kann: '
# Translating 'Example: Summarizing ' to 'Beispiel: Zusammenfassen '
# Translating 'Task: Read 5 ' to 'Aufgabe: Lesen Sie 5 '
# Translating ' papers and write a review about them' to '-Papiere und schreiben Sie eine Rezension darüber'
# Translating 'Scheduler agent' to 'Planungsagent'
# Translating 'Can: ' to 'Kann: '
# Translating 'Split complex tasks in sub-tasks' to 'Kann: '
# Translating 'Distribute tasks' to 'Kann: '
# Translating 'Example: Summarizing ' to 'Beispiel: Zusammenfassen '
# Translating '-Papers' to '-Papiere'
# Translating 'Log' to 'Protokoll'
# Translating 'Example: Summarizing ' to 'Beispiel: Zusammenfassen '
# Translating '-Papers' to '-Papiere'
# Translating 'Output' to 'Ausgabe'
# Translating 'Solving the same task with long-context prompting' to 'Die gleiche Aufgabe mit Long-Context-Prompting lösen'
# Translating 'Also possible; less flexible' to 'Auch möglich; weniger flexibel'
# Translating 'Solving the same task with long-context prompting' to 'Lösen der gleichen Aufgabe mit langem Kontexthervorrufen'
# Translating 'Output' to 'Ausgabe'
# Translating 'Agentic workflows vs. [long-context] prompting' to 'Agentische Workflows vs. [long-context] Aufforderung'
# Translating 'If agents had a success-rate of 99%, and we chain 5 agents in a workflow, our workflow’s success rate: 0.99' to 'Wenn Agenten eine Erfolgsrate von 99 % hätten und wir 5 Agenten in einem Workflow verketten, beträgt die Erfolgsrate unseres Workflows: 0.99'
# Translating 'Commercial models ' to 'Wenn Agenten eine Erfolgsrate von 99 % hätten und wir 5 Agenten in einem Workflow verketten, beträgt die Erfolgsrate unseres Workflows: 0.99'
# Translating 'may actually have a success-rate of 99% when calling a function.' to '5'
# Translating 'Open weight models may not.' to 'Wenn Agenten eine Erfolgsrate von 99 % hätten und wir 5 Agenten in einem Workflow verketten, beträgt die Erfolgsrate unseres Workflows: 0.99'
# Translating 'If agents had a success-rate of 90%, and we chain 5 agents in a workflow, our workflow’s success rate: 0.9' to 'Wenn Agenten eine Erfolgsrate von 99 % hätten und wir 5 Agenten in einem Workflow verketten, beträgt die Erfolgsrate unseres Workflows: 0.99'
# Translating '59%' to '95%'
# Translating 'Many frameworks solve this problem by calling functions in loops and checking results, e.g. for consistency -> ' to 'Wenn Agenten eine Erfolgsrate von 99 % hätten und wir 5 Agenten in einem Workflow verketten, beträgt die Erfolgsrate unseres Workflows: 0.99'
# Translating 'high costs!' to '5'
# Translating 'LLMs are everywhere' to 'LLMs sind überall'
# Translating 'are' to 'sind'
# Translating 'everywhere' to 'überall'
# Translating 'https://claude.ai/' to 'https://chatgpt.com/'
# Translating 'https://huggingface.co/chat/' to 'https://chatgpt.com/'
# Translating 'Institutional AI Infrastructure' to 'Institutionelle KI-Infrastruktur'
# Translating 'Many institutes have a l' to 'Viele Institute haben einen l'
# Translating 'ocal LLM Server' to 'okalen LLM-Server'
# Translating 'Great for teaching' to 'Viele Institute haben einen l'
# Translating 'Privacy preserving' to 'Viele Institute haben einen l'
# Translating 'Cross-institutional infrastructure, in Germany: ' to 'Viele Institute haben einen l'
# Translating 'KISSKI' to 'Viele Institute haben einen l'
# Translating ' ' to 'okalen LLM-Server'
# Translating 'ChatAI' to 'Großartig zum Lehren'
# Translating 'Helmholtz ' to 'Viele Institute haben einen l'
# Translating 'Blablador' to 'okalen LLM-Server'
# Translating 'Public, commercial, [free] infrastructure: ' to 'Viele Institute haben einen l'
# Translating 'Github' to 'Viele Institute haben einen l'
# Translating ' Models Marketplace' to 'okalen LLM-Server'
# Translating 'Huggingface' to 'Viele Institute haben einen l'
# Translating 'https://chat-ai.academiccloud.de/chat' to 'https://helmholtz-blablador.fz-juelich.de/'
# Translating 'are' to 'sind'
# Translating 'everywhere' to 'überall'
# Translating 'https://www.nature.com/articles/s41592-024-02310-w' to 'https://github.com/royerlab/napari-chatgpt'
# Translating 'are' to 'sind'
# Translating 'everywhere' to 'überall'
# Translating 'are' to 'sind'
# Translating 'everywhere' to 'überall'
# Translating 'are' to 'sind'
# Translating 'everywhere' to 'überall'
# Translating 'are' to 'sind'
# Translating 'everywhere' to 'überall'
# Translating ' Editor' to '-Editor'
# Translating 'Good Scientific Practice' to 'Gute Wissenschaftliche Praxis'
# Translating 'NATIONAL RESEARCH DATA MANAGEMENT INFRASTRUCTURE FOR MICROSCOPY AND BIOIMAGE ANALYSIS' to 'NATIONALE FORSCHUNGSDATENMANAGEMENT-INFRASTRUKTUR FÜR MIKROSKOPIE UND BIOBILDANALYSE'
# Translating 'GLOBAL BIOIMAGE ANALYST’S SOCIETY' to 'GLOBAL BIOIMAGE ANALYST'S SOCIETY'
# Translating 'Challenges' to 'Herausforderungen'
# Translating 'Rules…' to 'Regeln…'
# Translating 'Source: DFG (2023)' to 'Quelle: DFG (2023)'
# Translating 'Check your institutions’ and funders’ guidelines.' to 'Überprüfen Sie die Richtlinien Ihrer Institutionen und Förderer.'
# Translating '						 a human expert       an expert LLM ' to 'If'
# Translating 'You' to 'If'
# Translating 'should' to 'you'
# Translating ' …' to ' '
# Translating 'Understand' to 'If'
# Translating 'the' to 'you'
# Translating ' code (' to ' '
# Translating 'roughly' to 'use'
# Translating ')' to ' '
# Translating 'Question ' to 'If'
# Translating 'used' to ' '
# Translating ' ' to 'you'
# Translating 'methods' to ' '
# Translating 'Check ' to 'If'
# Translating 'results' to ' '
# Translating ' ' to 'you'
# Translating 'carefully' to ' '
# Translating 'Test code on ' to 'If'
# Translating 'samples' to ' '
# Translating ' ' to 'you'
# Translating 'the' to ' '
# Translating ' ' to 'use'
# Translating 'expert ' to ' '
# Translating 'didn‘t' to 'custom'
# Translating ' ' to ' code '
# Translating 'see' to 'written'
# Translating 'Good' to 'Gute'
# Translating 'scientific' to 'wissenschaftliche'
# Translating 'practice' to 'Praxis'
# Translating '						 a human expert       an expert LLM ' to 'If'
# Translating 'You' to 'If'
# Translating 'should' to 'you'
# Translating ' …' to ' '
# Translating 'Pay ' to 'If'
# Translating 'the' to ' '
# Translating ' expert' to 'you'
# Translating 'Mention ' to 'If'
# Translating 'the' to ' '
# Translating ' expert' to 'you'
# Translating 'Share ' to 'If'
# Translating 'responsibility' to ' '
# Translating 'Ask ' to 'If'
# Translating 'the' to ' '
# Translating ' expert ' to 'you'
# Translating 'endless' to ' '
# Translating ' ' to 'use'
# Translating 'questions' to ' '
# Translating 'Share ' to 'If'
# Translating 'how' to ' '
# Translating ' ' to 'you'
# Translating 'you' to ' '
# Translating ' ' to 'use'
# Translating 'prompted' to ' '
# Translating ' ' to 'custom'
# Translating 'the' to ' code '
# Translating ' expert' to 'written'
# Translating 'co-author' to 'Koautor'
# Translating 'methods' to 'Methoden'
# Translating 'Use ' to 'Verwendungs'
# Translating 'case' to 'fall'
# Translating 'Quantitatively' to 'Quantitativ'
# Translating 'biology' to 'Biologie'
# Translating 'Prompt: „' to 'Aufforderung: „'
# Translating 'Analyse' to 'Analysiere'
# Translating ' the following image by counting the bright blobs. Respond with the number only. ' to ' das folgende Bild, indem du die hellen Flecken zählst. Antworte nur mit der Zahl. '
# Translating 'May 2024' to 'Mai 2024'
# Translating 'Benchmarking image generation' to 'Benchmarking der Bildgenerierung'
# Translating 'When asking humans to evaluate results, make sure ' to 'Wenn man Menschen bittet, Ergebnisse zu bewerten, sollte man sicherstellen, '
# Translating 'they are the right target audience' to 'dass sie die richtige Zielgruppe sind'
# Translating 'Credit: ' to 'Gutschrift: '
# Translating '"Mandarin orange, axial view, MRI."' to '"Mandarine, axiale Ansicht, MRT."'
# Translating ' is licensed ' to ' ist lizenziert '
# Translating ' by Alexandr ' to ' von Alexandr '
# Translating 'https://haesleinhuepf.github.io/BioImageAnalysisNotebooks/07_prompt_engineering/02_generating_mri_images.html' to 'Gutschrift: '
# Translating ' ' to '"Mandarine, axiale Ansicht, MRT."'
# Translating 'https://twitter.com/haesleinhuepf/status/1659138282641342466' to 'Gutschrift: '
# Translating '  ' to '"Mandarine, axiale Ansicht, MRT."'
# Translating 'scores' to 'Werte'
# Translating 'Contrastive' to 'Kontrastive'
# Translating ' Language-Image ' to ' Sprach-Bild '
# Translating 'Pre' to 'Vor'
# Translating 'For' to 'Kontrastive'
# Translating ' ' to ' Sprach-Bild '
# Translating 'image' to 'Vor'
# Translating ' ' to '-Training (CLIP)'
# Translating 'describing' to 'Für'
# Translating 'Here: ' to 'Kontrastive'
# Translating 'Similarity' to ' Sprach-Bild '
# Translating ' ' to 'Vor'
# Translating 'between' to '-Training (CLIP)'
# Translating ' ' to 'Für'
# Translating 'image' to ' '
# Translating ' and prompt' to 'Bild'
# Translating 'CLIP scores' to 'CLIP-Bewertungen'
# Translating 'Example: Prompt optimization' to 'Beispiel: Prompt-Optimierung'
# Translating 'Quality measurement' to 'Qualitätsmessung'
# Translating 'Image generation' to 'Bildgenerierung'
# Translating 'Example' to 'Beispiel'
# Translating 'optimization' to 'Optimierung'
# Translating 'Always ' to 'Immer '
# Translating 'have' to 'ein'
# Translating ' a ' to ' '
# Translating 'control' to 'Kontrollexperiment'
# Translating 'experiment' to 'haben'
# Translating 'Benchmarking LLMs for Bio-image Analysis' to 'Benchmarking LLMs für Bio-Bildanalyse'
# Translating 'Use case: segment the image and measure the average area of objects.' to 'Anwendungsfall: das Bild segmentieren und die durchschnittliche Fläche der Objekte messen.'
# Translating 'https://github.com/haesleinhuepf/human-eval-bia' to 'https://www.biorxiv.org/content/10.1101/2024.04.19.590278v1'
# Translating ' ' to '    '
# Translating 'Example test-case inspired by ' to 'Beispiel-Testfall inspiriert von '
# Translating 'Prompt' to 'Eingabeaufforderung'
# Translating 'Reference solution' to 'Referenzlösung'
# Translating 'Unit test (excerpt)' to 'Unittest (Auszug)'
# Translating 'Chen at al 2021: ' to 'Chen et al 2021: '
# Translating 'https://www.biorxiv.org/content/10.1101/2024.04.19.590278v3' to 'Chen et al 2021: '
# Translating 'https://github.com/haesleinhuepf/human-eval-bia' to 'Chen et al 2021: '
# Translating ' ' to 'https://arxiv.org/abs/2107.03374'
# Translating 'Benchmarking LLMs for Bio-image Analysis' to 'Benchmarking LLMs für Bio-Bildanalyse'
# Translating 'Measuring pass-rate,' to 'Messung der Erfolgsquote,'
# Translating 'Testing ' to 'Messung der Erfolgsquote,'
# Translating 'functional correctness' to 'Testen '
# Translating 'Benchmarking LLMs for Bio-image Analysis' to 'Benchmarking LLMs für Bio-Bildanalyse'
# Translating 'Use case: segment the image and measure the average area of objects.' to 'Anwendungsfall: segmentiere das Bild und messe die durchschnittliche Fläche der Objekte.'
# Translating 'https://github.com/haesleinhuepf/human-eval-bia' to 'https://www.biorxiv.org/content/10.1101/2024.04.19.590278v1'
# Translating ' ' to '    '
# Translating 'Unit-test pass-rate (n=10):' to 'Unit-Test Erfolgsquote (n=10):'
# Translating 'Benchmarking LLMs for Bio-image Analysis' to 'Benchmarking LLMs für Bio-Bildanalyse'
# Translating '57 use-cases (yet), ' to '57 Anwendungsfälle (bisher), '
# Translating ' LLMs (yet), n=10' to ' LLMs (bisher), n=10'
# Translating 'https://github.com/haesleinhuepf/human-eval-bia/' to 'https://www.biorxiv.org/content/10.1101/2024.04.19.590278v3'
# Translating '   ' to ' '
# Translating 'Exercises' to 'Übungen'
# Translating 'Robert Haase' to 'Übungen'
# Translating 'Exercises' to 'Übungen'
# Translating ': Prompt Engineering Basics' to ': Grundlagen des Prompt Engineering'
# Translating 'Copy prompt' to 'Eingabeaufforderung kopieren'
# Translating 'Paste ' to 'Eingabeaufforderung kopieren'
# Translating 'it' to 'Einfügen '
# Translating ' ' to 'es'
# Translating 'into' to ' '
# Translating ' ' to 'in'
# Translating 'ChatGPT' to ' '
# Translating 'Read ' to 'Eingabeaufforderung kopieren'
# Translating 'response' to 'Einfügen '
# Translating 'Repeat ;-)' to 'Eingabeaufforderung kopieren'
# Translating 'Exercises' to 'Übungen'
# Translating 'basics' to 'Grundlagen'
# Translating 'https://scads.github.io/prompt-engineering-basics-2024/30_prompt_engineering.html' to 'https://scads.github.io/prompt-engineering-basics-2024/20_use_cases.html'
# Translating 'Exercises' to 'Übungen'
# Translating 'Requires' to 'Erfordert'
# Translating 'programming' to 'Programmier'
# Translating 'skills' to 'Kenntnisse'
# Translating 'Installation ' to 'Installations'
# Translating 'instructions' to 'anweisungen'
# Translating 'GPU-Workstation ' to 'Installations'
# Translating 'recommended' to 'anweisungen'
# Translating 'Exercise' to 'Übung'
# Translating ' API Key' to ' API-Schlüssel'
# Translating 'Create an ' to 'Erstellen Sie einen '
# Translating ' API Key (' to ' API-Schlüssel ('
# Translating 'usage' to 'Nutzung'
# Translating 'may' to 'kann'
# Translating 'cost' to 'Geld'
# Translating 'money' to 'kosten'
# Translating 'Exercise: Store the API key in your environment' to 'Übung: Speichern Sie den API-Schlüssel in Ihrer Umgebung'
# Translating 'Add the OPEN AI API Key to your environment variables' to 'Fügen Sie den OPEN AI API-Schlüssel zu Ihren Umgebungsvariablen hinzu'
# Translating 'Exercise' to 'Übung'
# Translating 'Alternatively, ' to 'Alternativ, '
# Translating 'zou' to 'könnten Sie'
# Translating ' can enter the OpenAI API-key like this at the beginning of notebooks:' to ' den OpenAI API-Schlüssel am Anfang von Notizbüchern so eingeben:'
# Translating 'But do not share the key with others!' to 'Alternativ, '
# Translating 'Exercise' to 'Übung'
# Translating 'Learn more…' to 'Erfahren Sie mehr…'
# Translating 'Summary & outlook' to 'Zusammenfassung & Ausblick'
# Translating 'Transformers / LLMs disrupt work in couple of fields' to 'Transformers / LLMs stören die Arbeit in einigen Bereichen'
# Translating 'Text production' to 'Transformers / LLMs stören die Arbeit in einigen Bereichen'
# Translating 'Programming' to 'Transformers / LLMs stören die Arbeit in einigen Bereichen'
# Translating 'Prompt engineering becomes a key skill in many disciplines' to 'Transformers / LLMs stören die Arbeit in einigen Bereichen'
# Translating 'Multi-modal LLMs and multi-agent systems may bring next breakthroughs soon' to 'Transformers / LLMs stören die Arbeit in einigen Bereichen'
# Translating 'How many cells are there?' to 'Wie viele Zellen gibt es?'
# Translating 'There are 4 cells. I used this code…' to 'Es gibt 4 Zellen. Ich habe diesen Code verwendet…'
# Translating 'Acknowledgements' to 'Danksagungen'
# Translating 'Funding' to 'Finanzierung'
# Translating 'Communities & platforms' to 'Gemeinschaften & Plattformen'
# Translating 'RH acknowledges the financial support by the Federal Ministry of Education and Research of Germany and by ' to 'RH erkennt die finanzielle Unterstützung durch das Bundesministerium für Bildung und Forschung Deutschlands und durch '
# Translating ' in the ' to ' im '
# Translating 'programme' to 'Programm'
# Translating ' Center of Excellence for AI-research „Center for Scalable Data Analytics and Artificial Intelligence Dresden/Leipzig“, project identification number: ScaDS.AI' to ' Exzellenzbereich für KI-Forschung „Center for Scalable Data Analytics and Artificial Intelligence Dresden/Leipzig“, Projektidentifikationsnummer: ScaDS.AI'
# Translating '(CZ ' to 'Loïc'
# Translating 'Biohub' to ' A. Royer '
# Translating ')' to '(CZ '
